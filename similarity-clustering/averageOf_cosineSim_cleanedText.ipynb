# %%
import pandas as pd
import numpy as np
import os
import glob
import json
import re
from collections import defaultdict

import torchtext
from torchtext.legacy.data import Example

from wikipedia2vec import Wikipedia2Vec

# %%
# Data with Entities

ROOT_FOLDER = "/raid6/home/ramraj/2021/ir/entity-reranking/Entity-Linking/"

# BENCHMARK_TRAIN_FOLD_FOLDER = os.path.join(ROOT_FOLDER, "benchmark-train-relevance-v2.0")
# BENCHMARK_TEST_FILE = os.path.join(ROOT_FOLDER, "test-data", "ramraj-test-data-top100-BM25.json")
# BENCHMARK_TRAIN_FOLD_FOLDER = os.path.join(ROOT_FOLDER, "Train-with-entities")
# BENCHMARK_TEST_FILE = os.path.join(ROOT_FOLDER, "Test-with-entities/ramraj-test-data-top100-BM25-opt.json")

BENCHMARK_TRAIN_FOLD_FOLDER = os.path.join(ROOT_FOLDER, "Train-with-entities-sepEntAndWords")
BENCHMARK_TEST_FILE = os.path.join(ROOT_FOLDER, "Test-with-entities/ramraj-test-data-top100-BM25-opt-entWordSEP.json")

# %% [markdown]
# # laod train

# %%
train_files = sorted(glob.glob(os.path.join(BENCHMARK_TRAIN_FOLD_FOLDER, "fold-*.json")))
print( len(train_files) )

train_data = []
for train_file in train_files:
    tmp_data = json.load(open(train_file, 'r'))
    train_data.extend(tmp_data)
    
len(train_data)
# Out:
# 1
# 1937

# %% [markdown]
# # load test

# %%
test_data = json.load(open(BENCHMARK_TEST_FILE, 'r'))
len(test_data)
# Out:
# 2254

# %% [markdown]
# # utils

# %%
def tokenise(text):
    # Replace annoying unicode with a space
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)
    # The following replacements are suggested in the paper
    # BidAF (Seo et al., 2016)
    text = text.replace("''", '" ')
    text = text.replace("``", '" ')

    # Space out punctuation
    space_list = "!\"#$%&()*+,-./:;<=>?@[\\]^_`{|}~"
    space_list = "!\"#$%&()*+,./:;<=>?@[\\]^_`{|}~"
    text = text.translate(str.maketrans({key: " {0} ".format(key) for key in space_list}))

    # space out singlequotes a bit better (and like stanford)
    text = text.replace("'", " '")
    
    # use any APIs
    text = text.replace('\t', '').replace('\n', '').lower().strip()
    return text

# %%
def alpha_numeric_filtering(text):
    regex = re.compile('[^a-zA-Z]')
    #First parameter is the replacement, second parameter is your input string
    return regex.sub(' ', text)

# %% [markdown]
# # load wikie

# %%
import torchtext.vocab as vocab

MODEL_FILE = "../entity-embedding-modelling/data/enwiki_20180420_300d.txt"
# https://github.com/pytorch/text/issues/722

custom_embeddings = vocab.Vectors(name = MODEL_FILE, cache="/raid6/home/ramraj/2021/ir/entity-reranking/entity-embedding-modelling/data/cache-enwiki")

# %%
PKL_MODEL_FILE = "../entity-embedding-modelling/data/enwiki_20180420_100d.pkl"
wiki2vec = Wikipedia2Vec.load(PKL_MODEL_FILE)

# %% [markdown]
# # vocab

# %%
PAD_TOKEN = '<PAD>'
SOS_TOKEN = '<SOS>'
UNK_TOKEN = '<UNK>'
EOS_TOKEN = '<EOS>'

MAX_Q_LENGTH = 20
MAX_D_LEN = 200

Q_TEXT = torchtext.legacy.data.Field(sequential=True, 
                                tokenize=lambda x: x.split('<SEP>'),
                                eos_token=EOS_TOKEN,
                                pad_token=PAD_TOKEN,
                                include_lengths=True,
                                batch_first=True,
                                fix_length=MAX_Q_LENGTH,
                                lower=True)

DOC_TEXT = torchtext.legacy.data.Field(sequential=True, 
                                tokenize=lambda x: x.split('<SEP>'),
                                eos_token=EOS_TOKEN,
                                pad_token=PAD_TOKEN,
                                include_lengths=True,
                                batch_first=True,
                                fix_length=MAX_D_LEN,
                                lower=True)

# %%
example_texts = []

FIELDS = [('doc_text', DOC_TEXT), ('q_text', Q_TEXT)]
# https://github.com/pytorch/text/issues/722


for train_data_sample in train_data:
    q_text = train_data_sample['qString']
    
    for rel_docs in train_data_sample['RelevantDocuments']:
        doc_text = rel_docs['docText']
        
        example_texts.append( Example.fromlist([doc_text, q_text] , FIELDS ) )
        
for test_data_sample in test_data:
    q_text = test_data_sample['qString']
    
    for rel_docs in test_data_sample['RelevantDocuments']:
        doc_text = rel_docs['docText']
        
        example_texts.append( Example.fromlist([doc_text, q_text] , FIELDS ) )

# %%
torchtext_dataset = torchtext.legacy.data.Dataset(example_texts, fields=FIELDS)

Q_TEXT.build_vocab(torchtext_dataset, vectors=custom_embeddings, vectors_cache="/raid6/home/ramraj/2021/ir/entity-reranking/entity-embedding-modelling/data/cache-enwiki")
DOC_TEXT.build_vocab(torchtext_dataset, vectors=custom_embeddings, vectors_cache="/raid6/home/ramraj/2021/ir/entity-reranking/entity-embedding-modelling/data/cache-enwiki")

print("======= Query ========")
print(len(Q_TEXT.vocab) )
print(Q_TEXT.vocab.vectors.size() )
print("======= Doc ========")
print( len(DOC_TEXT.vocab))
print( DOC_TEXT.vocab.vectors.size())
# Out:
# ======= Query ========
# 4004
# torch.Size([4004, 300])
# ======= Doc ========
# 229696
# torch.Size([229696, 300])

# %%
print( DOC_TEXT.vocab.stoi['university of southampton'], DOC_TEXT.vocab.itos[14] )
print( DOC_TEXT.vocab.stoi['fahrenheit'], DOC_TEXT.vocab.itos[3] )
# Out:
# 18345 new
# 16342

# %% [markdown]
# # dataset

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch

from pytorch_transformers import WarmupLinearSchedule, AdamW
from transformers import get_linear_schedule_with_warmup

def map_to_torch_float(encoding):
    encoding = torch.FloatTensor(encoding)
    encoding.requires_grad_(False)
    return encoding

def map_to_torch(encoding):
    encoding = torch.LongTensor(encoding)
    encoding.requires_grad_(False)
    return encoding


class TestTRECDataset(Dataset):
    def __init__(self, raw_data, q_field, d_field, query_max_len=20, max_len=512, is_train=True):
        self.is_train = is_train
        self.max_len = max_len
        self.query_max_len = query_max_len
        
        self.q_field = q_field
        self.d_field = d_field

        self.qLookup = defaultdict()
        self.dLookup = defaultdict()
        self.data_df = self.load_data(raw_data)
        self.len = len(self.data_df)
        
    def load_data(self, data):
        return_data = {'qID': [], 'qText': [], 'dID': [], 'dText': [], 'label': []}
        for data_sample in data:
            qID = data_sample['qID']
            qText = data_sample['qString']

            if qText == '': continue
            self.qLookup[qID] = qText

            for rel_docs in data_sample['RelevantDocuments']:
                dID = rel_docs['docID']
                docText = rel_docs['docText']
                
                if docText == '': continue
                self.dLookup[dID] = docText

                return_data['qID'].append(qID)
                return_data['dID'].append(dID)
                # return_data['qText'].append( qText )
                # return_data['dText'].append( docText )

        # df = pd.DataFrame(return_data, columns=["qID", "qText", "dID", "dText"])
        df = pd.DataFrame(return_data, columns=["qID", "dID"])
        return df
    
    def __len__(self):
        return self.len
    
    def __getitem__(self, index):
        index = index % self.len
        inst = self.data_df.loc[index]
        docID = inst['dID']
        qID = inst['qID']
        docText = self.dLookup[docID] # self.dLookup[docID] # inst['dText']
        qText = self.qLookup[qID] # self.qLookup[qID] # inst['qText']
        
        # print(qID)
        # print(qText)
        # print()
        # print(docID)
        # print(docText)

        # =============== prepare text before feed ===============
        q_text_processed = self.q_field.numericalize( self.q_field.pad([ [l for l in self.q_field.preprocess(qText) if l.strip()] ]) )
        d_text_processed = self.d_field.numericalize( self.d_field.pad([ [l for l in self.d_field.preprocess(docText) if l.strip()] ]) )

        return q_text_processed, d_text_processed, qID, docID
    

test_trec_dataset = TestTRECDataset(test_data, Q_TEXT, DOC_TEXT)
print( test_trec_dataset.__len__() )

q, d, qID, dID = test_trec_dataset.__getitem__(1)

print(q[0].shape)
print(d[0].shape)
# print(q[0][0].shape)
# print(out[1][0].shape)
# print(out[2][0].shape)
# print()
# print(out[0][0].shape)
# Out:
# 225156
# torch.Size([1, 20])
# torch.Size([1, 200])

# %%
q_str = []
for qq in q[0][0]:
    q_str.append(Q_TEXT.vocab.itos[qq])
print(' '.join( q_str) )
print()

q_str = []
for qq in d[0][0]:
    q_str.append(DOC_TEXT.vocab.itos[qq])
print(' '.join( q_str) )
print()
# Out:
# aftertaste <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
#
# aftertaste taste intensity food drink perception immediately food drink removed mouth aftertaste different food drink tin can vary intensity time unifying feature aftertaste perception food drink either swallowed spat neuroscience evolution taste aftertaste signal transduction taste receptor mouth brain yet fully understood however primary taste food processing area located insular cortex observed involved aftertaste perception <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# # Model

# %%
import typing
import torch.nn as nn
import torch.nn.functional as F


class SimScorer(nn.Module):
    def __init__(self, q_text_field, d_text_field, with_multi_layer_perceptron=True, mlp_num_layers=2, mlp_num_units=300, mlp_num_fan_out=1, padding_idx=1, embedding_freeze=True):
        super(SimScorer, self).__init__()
        self.with_multi_layer_perceptron = with_multi_layer_perceptron

        self.mlp_num_layers = mlp_num_layers
        self.mlp_num_units = mlp_num_units
        self.mlp_num_fan_out = mlp_num_fan_out
        self.q_text_field = q_text_field
        self.d_text_field = d_text_field
        self.padding_idx = padding_idx
        self.embedding_freeze = embedding_freeze
        self.build()
            
    def build(self):
        """
        Build model structure.
        """
        self.q_embedding = nn.Embedding.from_pretrained(self.q_text_field.vocab.vectors, padding_idx=self.padding_idx, freeze=self.embedding_freeze)
        self.d_embedding = nn.Embedding.from_pretrained(self.d_text_field.vocab.vectors, padding_idx=self.padding_idx, freeze=self.embedding_freeze)

    def forward(self, inputs):
        input_left, input_right = inputs['text_left'], inputs['text_right']
        
        input_left_emb = self.q_embedding(input_left)
        input_right_emb = self.d_embedding(input_right)
        
        # print("input_left_emb : ", input_left_emb.shape)
        # print("input_right_emb : ", input_right_emb.shape)
        
        input_left_emb_avg = torch.mean(input_left_emb, dim=1)
        input_right_emb_avg = torch.mean(input_right_emb, dim=1)
        
        # print("input_left_emb_avg : ", input_left_emb_avg.shape)
        # print("input_right_emb_avg : ", input_right_emb_avg.shape)
    
        # Dot product with cosine similarity.
        x = F.cosine_similarity(input_left_emb_avg, input_right_emb_avg)
        # x = x.unsqueeze(dim=1)
        # print("x : ", x.shape)

        return x


net = SimScorer(Q_TEXT, DOC_TEXT)
net.to(device)
print('Models built and ready to go!')

# tmp_q_text = torch.randint(low=1, high=30, size=(16, 20))
# tmp_d_text = torch.randint(low=1, high=30, size=(16, 200))
# print(tmp_q_text.shape)
# print(tmp_d_text.shape)

# input_text = {'text_left': tmp_q_text, 'text_right': tmp_d_text}

# output = net.forward(input_text)
# print(output)
# output.shape
# Out:
# Models built and ready to go!

# %%
# import config
import random
from bunch import Bunch
import time
import datetime

CONFIG_FILE = "config.json"

def format_time(elapsed_time):
    """
    Takes a time in seconds and returns a string hh:mm:ss
    """
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed_time)))
    return str(datetime.timedelta(seconds=elapsed_rounded)) # Format as hh:mm:ss

def get_config_from_json(json_file):
    """
        Get the config from a json file
        :param json_file:
        :return: config(namespace) or config(dictionary)
        """
    # parse the configurations from the config json file provided
    with open(json_file, 'r') as config_file:
        config_dict = json.load(config_file)

    # convert the dictionary to a namespace using bunch lib
    config = Bunch(config_dict)

    return config, config_dict

import torch
config, _ = get_config_from_json(CONFIG_FILE)
seed_val = config.cmd_args['seed']
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)
os.makedirs(config.data['results_dir'], exist_ok=True)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)


test_dataloader = DataLoader(dataset=test_trec_dataset,
                              batch_size=config.training["test_batch_size"],
                              pin_memory=device,
                              num_workers=config.training['num_workers'],
                              shuffle=True)
n_test_batches = len(test_dataloader)
print("Number of test batches : ", n_test_batches)
net.eval()
# Out:
# cuda
# Number of test batches :  880
# SimScorer(
#   (q_embedding): Embedding(4004, 300, padding_idx=1)
#   (d_embedding): Embedding(229696, 300, padding_idx=1)
# )

# %% [markdown]
# # test

# %%
qID_list = []
paraID_list = []
pScore_list = []
t1 = time.time()
for batch_idx, test_batch_data in enumerate(test_dataloader):
    # Converting these to cuda tensors
    q_text, d_text, qID, passageID = test_batch_data
#     print(type(q_text))
#     x = q_text[0]
#     y = q_text[1]
#     print(x.shape)
#     print(y.shape)
#     break
    q_text, d_text = torch.squeeze(q_text[0].to(device)), torch.squeeze(d_text[0]).to(device)

    with torch.no_grad():
        net_output = net({'text_left': q_text, 'text_right': d_text})
        net_output = net_output.detach().cpu().numpy()

        for i in range(len(qID)):
            qID_list.append(qID[i])
            paraID_list.append(passageID[i])
            pScore_list.append(net_output[i])
    elapsed = format_time(time.time() - t1)
    if batch_idx % 50 == 0:
        print('  Batch {:>5,}  of  {:>5,}  :  processed    Elapsed: {:}.'.format(batch_idx,
                                                                                 n_test_batches,
                                                                                 elapsed))

pScore_list = [float(e) for e in pScore_list]
predicted_df = pd.DataFrame({"qID": qID_list,
                             "pID": paraID_list,
                             "pScore": pScore_list}, columns=["qID", "pID", "pScore"])
if not config.cmd_args['mode'] == "experiment":
    predicted_df.to_csv(os.path.join(config.data['results_dir'], "predictions.csv"))
print()
# Out:
#   Batch     0  of    880  :  processed    Elapsed: 0:00:00.
#   Batch    50  of    880  :  processed    Elapsed: 0:00:06.
#   Batch   100  of    880  :  processed    Elapsed: 0:00:12.
#   Batch   150  of    880  :  processed    Elapsed: 0:00:18.
#   Batch   200  of    880  :  processed    Elapsed: 0:00:24.
#   Batch   250  of    880  :  processed    Elapsed: 0:00:31.
#   Batch   300  of    880  :  processed    Elapsed: 0:00:37.
#   Batch   350  of    880  :  processed    Elapsed: 0:00:43.
#   Batch   400  of    880  :  processed    Elapsed: 0:00:50.
#   Batch   450  of    880  :  processed    Elapsed: 0:00:56.
#   Batch   500  of    880  :  processed    Elapsed: 0:01:02.
#   Batch   550  of    880  :  processed    Elapsed: 0:01:08.
#   Batch   600  of    880  :  processed    Elapsed: 0:01:14.
#   Batch   650  of    880  :  processed    Elapsed: 0:01:21.
#   Batch   700  of    880  :  processed    Elapsed: 0:01:26.
#   Batch   750  of    880  :  processed    Elapsed: 0:01:32.
#   Batch   800  of    880  :  processed    Elapsed: 0:01:39.
#   Batch   850  of    880  :  processed    Elapsed: 0:01:45.

# %%
# ================================================
#               Reverse Sorting Relevance
# ================================================
predicted_df = predicted_df[['qID', 'pID', 'pScore']]
grouped_pred_df = predicted_df.groupby(["qID"])
num_queries = len(grouped_pred_df)
missing_q_sets = 0
save_ranked_file = os.path.join(config.data['results_dir'], "ranked.test.relevance.txt")
with open(save_ranked_file, 'w') as write_file:
    q_cnt = 1
    for name, row_group in grouped_pred_df:
        rank_cnt = 1

        # ======= SORTING =======
        sorted_row_group = row_group.sort_values(by='pScore', ascending=False, inplace=False)
        # =======================

        if len(sorted_row_group) != 100:
            # print(">>>>>>>>>>> Missing query %s with shape %s" % (name, sorted_row_group.shape))
            # print(">>>>>>>>>>> Missing query with size %s" % sorted_row_group.shape[0])
            missing_q_sets += 1

        for i, row in sorted_row_group.iterrows():
            write_file.write("%s\tQ0\t%s\t%s\t%s\trchan31\n" % \
                             (row["qID"], row["pID"], rank_cnt, row["pScore"]))
            rank_cnt += 1

        print("Finished composing for query number : %s / %s" % (q_cnt, num_queries))
        q_cnt += 1
print()
print("Missing query-doc pairs : ", missing_q_sets)
print("Done train, val, and test !!!")
# Out:
# Finished composing for query number : 1 / 2254
# Finished composing for query number : 2 / 2254
# Finished composing for query number : 3 / 2254
# Finished composing for query number : 4 / 2254
# Finished composing for query number : 5 / 2254
# Finished composing for query number : 6 / 2254
# Finished composing for query number : 7 / 2254
# Finished composing for query number : 8 / 2254
# Finished composing for query number : 9 / 2254
# Finished composing for query number : 10 / 2254
# Finished composing for query number : 11 / 2254
# Finished composing for query number : 12 / 2254
# Finished composing for query number : 13 / 2254
# Finished composing for query number : 14 / 2254
# Finished composing for query number : 15 / 2254
# Finished composing for query number : 16 / 2254
# Finished composing for query number : 17 / 2254
# Finished composing for query number : 18 / 2254
# Finished composing for query number : 19 / 2254
# Finished composing for query number : 20 / 2254
# Finished composing for query number : 21 / 2254
# Finished composing for query number : 22 / 2254
# Finished composing for query number : 23 / 2254
# Finished composing for query number : 24 / 2254
# Finished composing for query number : 25 / 2254
# Finished composing for query number : 26 / 2254
# Finished composing for query number : 27 / 2254
# Finished composing for query number : 28 / 2254
# Finished composing for query number : 29 / 2254
# Finished composing for query number : 30 / 2254
# Finished composing for query number : 31 / 2254
# Finished composing for query number : 32 / 2254
# Finished composing for query number : 33 / 2254
# Finished composing for query number : 34 / 2254
# Finished composing for query number : 35 / 2254
# Finished composing for query number : 36 / 2254
# Finished composing for query number : 37 / 2254
# Finished composing for query number : 38 / 2254
# Finished composing for query number : 39 / 2254
# Finished composing for query number : 40 / 2254
# Finished composing for query number : 41 / 2254
# Finished composing for query number : 42 / 2254
# Finished composing for query number : 43 / 2254
# Finished composing for query number : 44 / 2254
# Finished composing for query number : 45 / 2254
# Finished composing for query number : 46 / 2254
# Finished composing for query number : 47 / 2254
# Finished composing for query number : 48 / 2254
# Finished composing for query number : 49 / 2254
# Finished composing for query number : 50 / 2254
# Finished composing for query number : 51 / 2254
# Finished composing for query number : 52 / 2254
# Finished composing for query number : 53 / 2254
# Finished composing for query number : 54 / 2254
# Finished composing for query number : 55 / 2254
# Finished composing for query number : 56 / 2254
# Finished composing for query number : 57 / 2254
# Finished composing for query number : 58 / 2254
# Finished composing for query number : 59 / 2254
# Finished composing for query number : 60 / 2254
# Finished composing for query number : 61 / 2254
# Finished composing for query number : 62 / 2254
# Finished composing for query number : 63 / 2254
# Finished composing for query number : 64 / 2254
# Finished composing for query number : 65 / 2254
# Finished composing for query number : 66 / 2254
# Finished composing for query number : 67 / 2254
# Finished composing for query number : 68 / 2254
# Finished composing for query number : 69 / 2254
# Finished composing for query number : 70 / 2254
# Finished composing for query number : 71 / 2254
# Finished composing for query number : 72 / 2254
# Finished composing for query number : 73 / 2254
# Finished composing for query number : 74 / 2254
# Finished composing for query number : 75 / 2254
# Finished composing for query number : 76 / 2254
# Finished composing for query number : 77 / 2254
# Finished composing for query number : 78 / 2254
# Finished composing for query number : 79 / 2254
# Finished composing for query number : 80 / 2254
# Finished composing for query number : 81 / 2254
# Finished composing for query number : 82 / 2254
# Finished composing for query number : 83 / 2254
# Finished composing for query number : 84 / 2254
# Finished composing for query number : 85 / 2254
# Finished composing for query number : 86 / 2254
# Finished composing for query number : 87 / 2254
# Finished composing for query number : 88 / 2254
# Finished composing for query number : 89 / 2254
# Finished composing for query number : 90 / 2254
# Finished composing for query number : 91 / 2254
# Finished composing for query number : 92 / 2254
# Finished composing for query number : 93 / 2254
# Finished composing for query number : 94 / 2254
# Finished composing for query number : 95 / 2254
# Finished composing for query number : 96 / 2254
# Finished composing for query number : 97 / 2254
# Finished composing for query number : 98 / 2254
# Finished composing for query number : 99 / 2254
# Finished composing for query number : 100 / 2254
# Finished composing for query number : 101 / 2254
# Finished composing for query number : 102 / 2254
# Finished composing for query number : 103 / 2254
# Finished composing for query number : 104 / 2254
# Finished composing for query number : 105 / 2254
# Finished composing for query number : 106 / 2254
# Finished composing for query number : 107 / 2254
# Finished composing for query number : 108 / 2254
# Finished composing for query number : 109 / 2254
# Finished composing for query number : 110 / 2254
# Finished composing for query number : 111 / 2254
# Finished composing for query number : 112 / 2254
# Finished composing for query number : 113 / 2254
# Finished composing for query number : 114 / 2254
# Finished composing for query number : 115 / 2254
# Finished composing for query number : 116 / 2254
# Finished composing for query number : 117 / 2254
# Finished composing for query number : 118 / 2254
# Finished composing for query number : 119 / 2254
# Finished composing for query number : 120 / 2254
# Finished composing for query number : 121 / 2254
# Finished composing for query number : 122 / 2254
# Finished composing for query number : 123 / 2254
# Finished composing for query number : 124 / 2254
# Finished composing for query number : 125 / 2254
# Finished composing for query number : 126 / 2254
# Finished composing for query number : 127 / 2254
# Finished composing for query number : 128 / 2254
# Finished composing for query number : 129 / 2254
# Finished composing for query number : 130 / 2254
# Finished composing for query number : 131 / 2254
# Finished composing for query number : 132 / 2254
# Finished composing for query number : 133 / 2254
# Finished composing for query number : 134 / 2254
# Finished composing for query number : 135 / 2254
# Finished composing for query number : 136 / 2254
# Finished composing for query number : 137 / 2254
# Finished composing for query number : 138 / 2254
# Finished composing for query number : 139 / 2254
# Finished composing for query number : 140 / 2254
# Finished composing for query number : 141 / 2254
# Finished composing for query number : 142 / 2254
# Finished composing for query number : 143 / 2254
# Finished composing for query number : 144 / 2254
# Finished composing for query number : 145 / 2254
# Finished composing for query number : 146 / 2254
# Finished composing for query number : 147 / 2254
# Finished composing for query number : 148 / 2254
# Finished composing for query number : 149 / 2254
# Finished composing for query number : 150 / 2254
# Finished composing for query number : 151 / 2254
# Finished composing for query number : 152 / 2254
# Finished composing for query number : 153 / 2254
# Finished composing for query number : 154 / 2254
# Finished composing for query number : 155 / 2254
# Finished composing for query number : 156 / 2254
# Finished composing for query number : 157 / 2254
# Finished composing for query number : 158 / 2254
# Finished composing for query number : 159 / 2254
# Finished composing for query number : 160 / 2254
# Finished composing for query number : 161 / 2254
# Finished composing for query number : 162 / 2254
# Finished composing for query number : 163 / 2254
# Finished composing for query number : 164 / 2254
# Finished composing for query number : 165 / 2254
# Finished composing for query number : 166 / 2254
# Finished composing for query number : 167 / 2254
# Finished composing for query number : 168 / 2254
# Finished composing for query number : 169 / 2254
# Finished composing for query number : 170 / 2254
# Finished composing for query number : 171 / 2254
# Finished composing for query number : 172 / 2254
# Finished composing for query number : 173 / 2254
# Finished composing for query number : 174 / 2254
# Finished composing for query number : 175 / 2254
# Finished composing for query number : 176 / 2254
# Finished composing for query number : 177 / 2254
# Finished composing for query number : 178 / 2254
# Finished composing for query number : 179 / 2254
# Finished composing for query number : 180 / 2254
# Finished composing for query number : 181 / 2254
# Finished composing for query number : 182 / 2254
# Finished composing for query number : 183 / 2254
# Finished composing for query number : 184 / 2254
# Finished composing for query number : 185 / 2254
# Finished composing for query number : 186 / 2254
# Finished composing for query number : 187 / 2254
# Finished composing for query number : 188 / 2254
# Finished composing for query number : 189 / 2254
# Finished composing for query number : 190 / 2254
# Finished composing for query number : 191 / 2254
# Finished composing for query number : 192 / 2254
# Finished composing for query number : 193 / 2254
# Finished composing for query number : 194 / 2254
# Finished composing for query number : 195 / 2254
# Finished composing for query number : 196 / 2254
# Finished composing for query number : 197 / 2254
# Finished composing for query number : 198 / 2254
# Finished composing for query number : 199 / 2254
# Finished composing for query number : 200 / 2254
# Finished composing for query number : 201 / 2254
# Finished composing for query number : 202 / 2254
# Finished composing for query number : 203 / 2254
# Finished composing for query number : 204 / 2254
# Finished composing for query number : 205 / 2254
# Finished composing for query number : 206 / 2254
# Finished composing for query number : 207 / 2254
# Finished composing for query number : 208 / 2254
# Finished composing for query number : 209 / 2254
# Finished composing for query number : 210 / 2254
# Finished composing for query number : 211 / 2254
# Finished composing for query number : 212 / 2254
# Finished composing for query number : 213 / 2254
# Finished composing for query number : 214 / 2254
# Finished composing for query number : 215 / 2254
# Finished composing for query number : 216 / 2254
# Finished composing for query number : 217 / 2254
# Finished composing for query number : 218 / 2254
# Finished composing for query number : 219 / 2254
# Finished composing for query number : 220 / 2254
# Finished composing for query number : 221 / 2254
# Finished composing for query number : 222 / 2254
# Finished composing for query number : 223 / 2254
# Finished composing for query number : 224 / 2254
# Finished composing for query number : 225 / 2254
# Finished composing for query number : 226 / 2254
# Finished composing for query number : 227 / 2254
# Finished composing for query number : 228 / 2254
# Finished composing for query number : 229 / 2254
# Finished composing for query number : 230 / 2254
# Finished composing for query number : 231 / 2254
# Finished composing for query number : 232 / 2254
# Finished composing for query number : 233 / 2254
# Finished composing for query number : 234 / 2254
# Finished composing for query number : 235 / 2254
# Finished composing for query number : 236 / 2254
# Finished composing for query number : 237 / 2254
# Finished composing for query number : 238 / 2254
# Finished composing for query number : 239 / 2254
# Finished composing for query number : 240 / 2254
# Finished composing for query number : 241 / 2254
# Finished composing for query number : 242 / 2254
# Finished composing for query number : 243 / 2254
# Finished composing for query number : 244 / 2254
# Finished composing for query number : 245 / 2254
# Finished composing for query number : 246 / 2254
# Finished composing for query number : 247 / 2254
# Finished composing for query number : 248 / 2254
# Finished composing for query number : 249 / 2254
# Finished composing for query number : 250 / 2254
# Finished composing for query number : 251 / 2254
# Finished composing for query number : 252 / 2254
# Finished composing for query number : 253 / 2254
# Finished composing for query number : 254 / 2254
# Finished composing for query number : 255 / 2254
# Finished composing for query number : 256 / 2254
# Finished composing for query number : 257 / 2254
# Finished composing for query number : 258 / 2254
# Finished composing for query number : 259 / 2254
# Finished composing for query number : 260 / 2254
# Finished composing for query number : 261 / 2254
# Finished composing for query number : 262 / 2254
# Finished composing for query number : 263 / 2254
# Finished composing for query number : 264 / 2254
# Finished composing for query number : 265 / 2254
# Finished composing for query number : 266 / 2254
# Finished composing for query number : 267 / 2254
# Finished composing for query number : 268 / 2254
# Finished composing for query number : 269 / 2254
# Finished composing for query number : 270 / 2254
# Finished composing for query number : 271 / 2254
# Finished composing for query number : 272 / 2254
# Finished composing for query number : 273 / 2254
# Finished composing for query number : 274 / 2254
# Finished composing for query number : 275 / 2254
# Finished composing for query number : 276 / 2254
# Finished composing for query number : 277 / 2254
# Finished composing for query number : 278 / 2254
# Finished composing for query number : 279 / 2254
# Finished composing for query number : 280 / 2254
# Finished composing for query number : 281 / 2254
# Finished composing for query number : 282 / 2254
# Finished composing for query number : 283 / 2254
# Finished composing for query number : 284 / 2254
# Finished composing for query number : 285 / 2254
# Finished composing for query number : 286 / 2254
# Finished composing for query number : 287 / 2254
# Finished composing for query number : 288 / 2254
# Finished composing for query number : 289 / 2254
# Finished composing for query number : 290 / 2254
# Finished composing for query number : 291 / 2254
# Finished composing for query number : 292 / 2254
# Finished composing for query number : 293 / 2254
# Finished composing for query number : 294 / 2254
# Finished composing for query number : 295 / 2254
# Finished composing for query number : 296 / 2254
# Finished composing for query number : 297 / 2254
# Finished composing for query number : 298 / 2254
# Finished composing for query number : 299 / 2254
# Finished composing for query number : 300 / 2254
# Finished composing for query number : 301 / 2254
# Finished composing for query number : 302 / 2254
# Finished composing for query number : 303 / 2254
# Finished composing for query number : 304 / 2254
# Finished composing for query number : 305 / 2254
# Finished composing for query number : 306 / 2254
# Finished composing for query number : 307 / 2254
# Finished composing for query number : 308 / 2254
# Finished composing for query number : 309 / 2254
# Finished composing for query number : 310 / 2254
# Finished composing for query number : 311 / 2254
# Finished composing for query number : 312 / 2254
# Finished composing for query number : 313 / 2254
# Finished composing for query number : 314 / 2254
# Finished composing for query number : 315 / 2254
# Finished composing for query number : 316 / 2254
# Finished composing for query number : 317 / 2254
# Finished composing for query number : 318 / 2254
# Finished composing for query number : 319 / 2254
# Finished composing for query number : 320 / 2254
# Finished composing for query number : 321 / 2254
# Finished composing for query number : 322 / 2254
# Finished composing for query number : 323 / 2254
# Finished composing for query number : 324 / 2254
# Finished composing for query number : 325 / 2254
# Finished composing for query number : 326 / 2254
# Finished composing for query number : 327 / 2254
# Finished composing for query number : 328 / 2254
# Finished composing for query number : 329 / 2254
# Finished composing for query number : 330 / 2254
# Finished composing for query number : 331 / 2254
# Finished composing for query number : 332 / 2254
# Finished composing for query number : 333 / 2254
# Finished composing for query number : 334 / 2254
# Finished composing for query number : 335 / 2254
# Finished composing for query number : 336 / 2254
# Finished composing for query number : 337 / 2254
# Finished composing for query number : 338 / 2254
# Finished composing for query number : 339 / 2254
# Finished composing for query number : 340 / 2254
# Finished composing for query number : 341 / 2254
# Finished composing for query number : 342 / 2254
# Finished composing for query number : 343 / 2254
# Finished composing for query number : 344 / 2254
# Finished composing for query number : 345 / 2254
# Finished composing for query number : 346 / 2254
# Finished composing for query number : 347 / 2254
# Finished composing for query number : 348 / 2254
# Finished composing for query number : 349 / 2254
# Finished composing for query number : 350 / 2254
# Finished composing for query number : 351 / 2254
# Finished composing for query number : 352 / 2254
# Finished composing for query number : 353 / 2254
# Finished composing for query number : 354 / 2254
# Finished composing for query number : 355 / 2254
# Finished composing for query number : 356 / 2254
# Finished composing for query number : 357 / 2254
# Finished composing for query number : 358 / 2254
# Finished composing for query number : 359 / 2254
# Finished composing for query number : 360 / 2254
# Finished composing for query number : 361 / 2254
# Finished composing for query number : 362 / 2254
# Finished composing for query number : 363 / 2254
# Finished composing for query number : 364 / 2254
# Finished composing for query number : 365 / 2254
# Finished composing for query number : 366 / 2254
# Finished composing for query number : 367 / 2254
# Finished composing for query number : 368 / 2254
# Finished composing for query number : 369 / 2254
# Finished composing for query number : 370 / 2254
# Finished composing for query number : 371 / 2254
# Finished composing for query number : 372 / 2254
# Finished composing for query number : 373 / 2254
# Finished composing for query number : 374 / 2254
# Finished composing for query number : 375 / 2254
# Finished composing for query number : 376 / 2254
# Finished composing for query number : 377 / 2254
# Finished composing for query number : 378 / 2254
# Finished composing for query number : 379 / 2254
# Finished composing for query number : 380 / 2254
# Finished composing for query number : 381 / 2254
# Finished composing for query number : 382 / 2254
# Finished composing for query number : 383 / 2254
# Finished composing for query number : 384 / 2254
# Finished composing for query number : 385 / 2254
# Finished composing for query number : 386 / 2254
# Finished composing for query number : 387 / 2254
# Finished composing for query number : 388 / 2254
# Finished composing for query number : 389 / 2254
# Finished composing for query number : 390 / 2254
# Finished composing for query number : 391 / 2254
# Finished composing for query number : 392 / 2254
# Finished composing for query number : 393 / 2254
# Finished composing for query number : 394 / 2254
# Finished composing for query number : 395 / 2254
# Finished composing for query number : 396 / 2254
# Finished composing for query number : 397 / 2254
# Finished composing for query number : 398 / 2254
# Finished composing for query number : 399 / 2254
# Finished composing for query number : 400 / 2254
# Finished composing for query number : 401 / 2254
# Finished composing for query number : 402 / 2254
# Finished composing for query number : 403 / 2254
# Finished composing for query number : 404 / 2254
# Finished composing for query number : 405 / 2254
# Finished composing for query number : 406 / 2254
# Finished composing for query number : 407 / 2254
# Finished composing for query number : 408 / 2254
# Finished composing for query number : 409 / 2254
# Finished composing for query number : 410 / 2254
# Finished composing for query number : 411 / 2254
# Finished composing for query number : 412 / 2254
# Finished composing for query number : 413 / 2254
# Finished composing for query number : 414 / 2254
# Finished composing for query number : 415 / 2254
# Finished composing for query number : 416 / 2254
# Finished composing for query number : 417 / 2254
# Finished composing for query number : 418 / 2254
# Finished composing for query number : 419 / 2254
# Finished composing for query number : 420 / 2254
# Finished composing for query number : 421 / 2254
# Finished composing for query number : 422 / 2254
# Finished composing for query number : 423 / 2254
# Finished composing for query number : 424 / 2254
# Finished composing for query number : 425 / 2254
# Finished composing for query number : 426 / 2254
# Finished composing for query number : 427 / 2254
# Finished composing for query number : 428 / 2254
# Finished composing for query number : 429 / 2254
# Finished composing for query number : 430 / 2254
# Finished composing for query number : 431 / 2254
# Finished composing for query number : 432 / 2254
# Finished composing for query number : 433 / 2254
# Finished composing for query number : 434 / 2254
# Finished composing for query number : 435 / 2254
# Finished composing for query number : 436 / 2254
# Finished composing for query number : 437 / 2254
# Finished composing for query number : 438 / 2254
# Finished composing for query number : 439 / 2254
# Finished composing for query number : 440 / 2254
# Finished composing for query number : 441 / 2254
# Finished composing for query number : 442 / 2254
# Finished composing for query number : 443 / 2254
# Finished composing for query number : 444 / 2254
# Finished composing for query number : 445 / 2254
# Finished composing for query number : 446 / 2254
# Finished composing for query number : 447 / 2254
# Finished composing for query number : 448 / 2254
# Finished composing for query number : 449 / 2254
# Finished composing for query number : 450 / 2254
# Finished composing for query number : 451 / 2254
# Finished composing for query number : 452 / 2254
# Finished composing for query number : 453 / 2254
# Finished composing for query number : 454 / 2254
# Finished composing for query number : 455 / 2254
# Finished composing for query number : 456 / 2254
# Finished composing for query number : 457 / 2254
# Finished composing for query number : 458 / 2254
# Finished composing for query number : 459 / 2254
# Finished composing for query number : 460 / 2254
# Finished composing for query number : 461 / 2254
# Finished composing for query number : 462 / 2254
# Finished composing for query number : 463 / 2254
# Finished composing for query number : 464 / 2254
# Finished composing for query number : 465 / 2254
# Finished composing for query number : 466 / 2254
# Finished composing for query number : 467 / 2254
# Finished composing for query number : 468 / 2254
# Finished composing for query number : 469 / 2254
# Finished composing for query number : 470 / 2254
# Finished composing for query number : 471 / 2254
# Finished composing for query number : 472 / 2254
# Finished composing for query number : 473 / 2254
# Finished composing for query number : 474 / 2254
# Finished composing for query number : 475 / 2254
# Finished composing for query number : 476 / 2254
# Finished composing for query number : 477 / 2254
# Finished composing for query number : 478 / 2254
# Finished composing for query number : 479 / 2254
# Finished composing for query number : 480 / 2254
# Finished composing for query number : 481 / 2254
# Finished composing for query number : 482 / 2254
# Finished composing for query number : 483 / 2254
# Finished composing for query number : 484 / 2254
# Finished composing for query number : 485 / 2254
# Finished composing for query number : 486 / 2254
# Finished composing for query number : 487 / 2254
# Finished composing for query number : 488 / 2254
# Finished composing for query number : 489 / 2254
# Finished composing for query number : 490 / 2254
# Finished composing for query number : 491 / 2254
# Finished composing for query number : 492 / 2254
# Finished composing for query number : 493 / 2254
# Finished composing for query number : 494 / 2254
# Finished composing for query number : 495 / 2254
# Finished composing for query number : 496 / 2254
# Finished composing for query number : 497 / 2254
# Finished composing for query number : 498 / 2254
# Finished composing for query number : 499 / 2254
# Finished composing for query number : 500 / 2254
# Finished composing for query number : 501 / 2254
# Finished composing for query number : 502 / 2254
# Finished composing for query number : 503 / 2254
# Finished composing for query number : 504 / 2254
# Finished composing for query number : 505 / 2254
# Finished composing for query number : 506 / 2254
# Finished composing for query number : 507 / 2254
# Finished composing for query number : 508 / 2254
# Finished composing for query number : 509 / 2254
# Finished composing for query number : 510 / 2254
# Finished composing for query number : 511 / 2254
# Finished composing for query number : 512 / 2254
# Finished composing for query number : 513 / 2254
# Finished composing for query number : 514 / 2254
# Finished composing for query number : 515 / 2254
# Finished composing for query number : 516 / 2254
# Finished composing for query number : 517 / 2254
# Finished composing for query number : 518 / 2254
# Finished composing for query number : 519 / 2254
# Finished composing for query number : 520 / 2254
# Finished composing for query number : 521 / 2254
# Finished composing for query number : 522 / 2254
# Finished composing for query number : 523 / 2254
# Finished composing for query number : 524 / 2254
# Finished composing for query number : 525 / 2254
# Finished composing for query number : 526 / 2254
# Finished composing for query number : 527 / 2254
# Finished composing for query number : 528 / 2254
# Finished composing for query number : 529 / 2254
# Finished composing for query number : 530 / 2254
# Finished composing for query number : 531 / 2254
# Finished composing for query number : 532 / 2254
# Finished composing for query number : 533 / 2254
# Finished composing for query number : 534 / 2254
# Finished composing for query number : 535 / 2254
# Finished composing for query number : 536 / 2254
# Finished composing for query number : 537 / 2254
# Finished composing for query number : 538 / 2254
# Finished composing for query number : 539 / 2254
# Finished composing for query number : 540 / 2254
# Finished composing for query number : 541 / 2254
# Finished composing for query number : 542 / 2254
# Finished composing for query number : 543 / 2254
# Finished composing for query number : 544 / 2254
# Finished composing for query number : 545 / 2254
# Finished composing for query number : 546 / 2254
# Finished composing for query number : 547 / 2254
# Finished composing for query number : 548 / 2254
# Finished composing for query number : 549 / 2254
# Finished composing for query number : 550 / 2254
# Finished composing for query number : 551 / 2254
# Finished composing for query number : 552 / 2254
# Finished composing for query number : 553 / 2254
# Finished composing for query number : 554 / 2254
# Finished composing for query number : 555 / 2254
# Finished composing for query number : 556 / 2254
# Finished composing for query number : 557 / 2254
# Finished composing for query number : 558 / 2254
# Finished composing for query number : 559 / 2254
# Finished composing for query number : 560 / 2254
# Finished composing for query number : 561 / 2254
# Finished composing for query number : 562 / 2254
# Finished composing for query number : 563 / 2254
# Finished composing for query number : 564 / 2254
# Finished composing for query number : 565 / 2254
# Finished composing for query number : 566 / 2254
# Finished composing for query number : 567 / 2254
# Finished composing for query number : 568 / 2254
# Finished composing for query number : 569 / 2254
# Finished composing for query number : 570 / 2254
# Finished composing for query number : 571 / 2254
# Finished composing for query number : 572 / 2254
# Finished composing for query number : 573 / 2254
# Finished composing for query number : 574 / 2254
# Finished composing for query number : 575 / 2254
# Finished composing for query number : 576 / 2254
# Finished composing for query number : 577 / 2254
# Finished composing for query number : 578 / 2254
# Finished composing for query number : 579 / 2254
# Finished composing for query number : 580 / 2254
# Finished composing for query number : 581 / 2254
# Finished composing for query number : 582 / 2254
# Finished composing for query number : 583 / 2254
# Finished composing for query number : 584 / 2254
# Finished composing for query number : 585 / 2254
# Finished composing for query number : 586 / 2254
# Finished composing for query number : 587 / 2254
# Finished composing for query number : 588 / 2254
# Finished composing for query number : 589 / 2254
# Finished composing for query number : 590 / 2254
# Finished composing for query number : 591 / 2254
# Finished composing for query number : 592 / 2254
# Finished composing for query number : 593 / 2254
# Finished composing for query number : 594 / 2254
# Finished composing for query number : 595 / 2254
# Finished composing for query number : 596 / 2254
# Finished composing for query number : 597 / 2254
# Finished composing for query number : 598 / 2254
# Finished composing for query number : 599 / 2254
# Finished composing for query number : 600 / 2254
# Finished composing for query number : 601 / 2254
# Finished composing for query number : 602 / 2254
# Finished composing for query number : 603 / 2254
# Finished composing for query number : 604 / 2254
# Finished composing for query number : 605 / 2254
# Finished composing for query number : 606 / 2254
# Finished composing for query number : 607 / 2254
# Finished composing for query number : 608 / 2254
# Finished composing for query number : 609 / 2254
# Finished composing for query number : 610 / 2254
# Finished composing for query number : 611 / 2254
# Finished composing for query number : 612 / 2254
# Finished composing for query number : 613 / 2254
# Finished composing for query number : 614 / 2254
# Finished composing for query number : 615 / 2254
# Finished composing for query number : 616 / 2254
# Finished composing for query number : 617 / 2254
# Finished composing for query number : 618 / 2254
# Finished composing for query number : 619 / 2254
# Finished composing for query number : 620 / 2254
# Finished composing for query number : 621 / 2254
# Finished composing for query number : 622 / 2254
# Finished composing for query number : 623 / 2254
# Finished composing for query number : 624 / 2254
# Finished composing for query number : 625 / 2254
# Finished composing for query number : 626 / 2254
# Finished composing for query number : 627 / 2254
# Finished composing for query number : 628 / 2254
# Finished composing for query number : 629 / 2254
# Finished composing for query number : 630 / 2254
# Finished composing for query number : 631 / 2254
# Finished composing for query number : 632 / 2254
# Finished composing for query number : 633 / 2254
# Finished composing for query number : 634 / 2254
# Finished composing for query number : 635 / 2254
# Finished composing for query number : 636 / 2254
# Finished composing for query number : 637 / 2254
# Finished composing for query number : 638 / 2254
# Finished composing for query number : 639 / 2254
# Finished composing for query number : 640 / 2254
# Finished composing for query number : 641 / 2254
# Finished composing for query number : 642 / 2254
# Finished composing for query number : 643 / 2254
# Finished composing for query number : 644 / 2254
# Finished composing for query number : 645 / 2254
# Finished composing for query number : 646 / 2254
# Finished composing for query number : 647 / 2254
# Finished composing for query number : 648 / 2254
# Finished composing for query number : 649 / 2254
# Finished composing for query number : 650 / 2254
# Finished composing for query number : 651 / 2254
# Finished composing for query number : 652 / 2254
# Finished composing for query number : 653 / 2254
# Finished composing for query number : 654 / 2254
# Finished composing for query number : 655 / 2254
# Finished composing for query number : 656 / 2254
# Finished composing for query number : 657 / 2254
# Finished composing for query number : 658 / 2254
# Finished composing for query number : 659 / 2254
# Finished composing for query number : 660 / 2254
# Finished composing for query number : 661 / 2254
# Finished composing for query number : 662 / 2254
# Finished composing for query number : 663 / 2254
# Finished composing for query number : 664 / 2254
# Finished composing for query number : 665 / 2254
# Finished composing for query number : 666 / 2254
# Finished composing for query number : 667 / 2254
# Finished composing for query number : 668 / 2254
# Finished composing for query number : 669 / 2254
# Finished composing for query number : 670 / 2254
# Finished composing for query number : 671 / 2254
# Finished composing for query number : 672 / 2254
# Finished composing for query number : 673 / 2254
# Finished composing for query number : 674 / 2254
# Finished composing for query number : 675 / 2254
# Finished composing for query number : 676 / 2254
# Finished composing for query number : 677 / 2254
# Finished composing for query number : 678 / 2254
# Finished composing for query number : 679 / 2254
# Finished composing for query number : 680 / 2254
# Finished composing for query number : 681 / 2254
# Finished composing for query number : 682 / 2254
# Finished composing for query number : 683 / 2254
# Finished composing for query number : 684 / 2254
# Finished composing for query number : 685 / 2254
# Finished composing for query number : 686 / 2254
# Finished composing for query number : 687 / 2254
# Finished composing for query number : 688 / 2254
# Finished composing for query number : 689 / 2254
# Finished composing for query number : 690 / 2254
# Finished composing for query number : 691 / 2254
# Finished composing for query number : 692 / 2254
# Finished composing for query number : 693 / 2254
# Finished composing for query number : 694 / 2254
# Finished composing for query number : 695 / 2254
# Finished composing for query number : 696 / 2254
# Finished composing for query number : 697 / 2254
# Finished composing for query number : 698 / 2254
# Finished composing for query number : 699 / 2254
# Finished composing for query number : 700 / 2254
# Finished composing for query number : 701 / 2254
# Finished composing for query number : 702 / 2254
# Finished composing for query number : 703 / 2254
# Finished composing for query number : 704 / 2254
# Finished composing for query number : 705 / 2254
# Finished composing for query number : 706 / 2254
# Finished composing for query number : 707 / 2254
# Finished composing for query number : 708 / 2254
# Finished composing for query number : 709 / 2254
# Finished composing for query number : 710 / 2254
# Finished composing for query number : 711 / 2254
# Finished composing for query number : 712 / 2254
# Finished composing for query number : 713 / 2254
# Finished composing for query number : 714 / 2254
# Finished composing for query number : 715 / 2254
# Finished composing for query number : 716 / 2254
# Finished composing for query number : 717 / 2254
# Finished composing for query number : 718 / 2254
# Finished composing for query number : 719 / 2254
# Finished composing for query number : 720 / 2254
# Finished composing for query number : 721 / 2254
# Finished composing for query number : 722 / 2254
# Finished composing for query number : 723 / 2254
# Finished composing for query number : 724 / 2254
# Finished composing for query number : 725 / 2254
# Finished composing for query number : 726 / 2254
# Finished composing for query number : 727 / 2254
# Finished composing for query number : 728 / 2254
# Finished composing for query number : 729 / 2254
# Finished composing for query number : 730 / 2254
# Finished composing for query number : 731 / 2254
# Finished composing for query number : 732 / 2254
# Finished composing for query number : 733 / 2254
# Finished composing for query number : 734 / 2254
# Finished composing for query number : 735 / 2254
# Finished composing for query number : 736 / 2254
# Finished composing for query number : 737 / 2254
# Finished composing for query number : 738 / 2254
# Finished composing for query number : 739 / 2254
# Finished composing for query number : 740 / 2254
# Finished composing for query number : 741 / 2254
# Finished composing for query number : 742 / 2254
# Finished composing for query number : 743 / 2254
# Finished composing for query number : 744 / 2254
# Finished composing for query number : 745 / 2254
# Finished composing for query number : 746 / 2254
# Finished composing for query number : 747 / 2254
# Finished composing for query number : 748 / 2254
# Finished composing for query number : 749 / 2254
# Finished composing for query number : 750 / 2254
# Finished composing for query number : 751 / 2254
# Finished composing for query number : 752 / 2254
# Finished composing for query number : 753 / 2254
# Finished composing for query number : 754 / 2254
# Finished composing for query number : 755 / 2254
# Finished composing for query number : 756 / 2254
# Finished composing for query number : 757 / 2254
# Finished composing for query number : 758 / 2254
# Finished composing for query number : 759 / 2254
# Finished composing for query number : 760 / 2254
# Finished composing for query number : 761 / 2254
# Finished composing for query number : 762 / 2254
# Finished composing for query number : 763 / 2254
# Finished composing for query number : 764 / 2254
# Finished composing for query number : 765 / 2254
# Finished composing for query number : 766 / 2254
# Finished composing for query number : 767 / 2254
# Finished composing for query number : 768 / 2254
# Finished composing for query number : 769 / 2254
# Finished composing for query number : 770 / 2254
# Finished composing for query number : 771 / 2254
# Finished composing for query number : 772 / 2254
# Finished composing for query number : 773 / 2254
# Finished composing for query number : 774 / 2254
# Finished composing for query number : 775 / 2254
# Finished composing for query number : 776 / 2254
# Finished composing for query number : 777 / 2254
# Finished composing for query number : 778 / 2254
# Finished composing for query number : 779 / 2254
# Finished composing for query number : 780 / 2254
# Finished composing for query number : 781 / 2254
# Finished composing for query number : 782 / 2254
# Finished composing for query number : 783 / 2254
# Finished composing for query number : 784 / 2254
# Finished composing for query number : 785 / 2254
# Finished composing for query number : 786 / 2254
# Finished composing for query number : 787 / 2254
# Finished composing for query number : 788 / 2254
# Finished composing for query number : 789 / 2254
# Finished composing for query number : 790 / 2254
# Finished composing for query number : 791 / 2254
# Finished composing for query number : 792 / 2254
# Finished composing for query number : 793 / 2254
# Finished composing for query number : 794 / 2254
# Finished composing for query number : 795 / 2254
# Finished composing for query number : 796 / 2254
# Finished composing for query number : 797 / 2254
# Finished composing for query number : 798 / 2254
# Finished composing for query number : 799 / 2254
# Finished composing for query number : 800 / 2254
# Finished composing for query number : 801 / 2254
# Finished composing for query number : 802 / 2254
# Finished composing for query number : 803 / 2254
# Finished composing for query number : 804 / 2254
# Finished composing for query number : 805 / 2254
# Finished composing for query number : 806 / 2254
# Finished composing for query number : 807 / 2254
# Finished composing for query number : 808 / 2254
# Finished composing for query number : 809 / 2254
# Finished composing for query number : 810 / 2254
# Finished composing for query number : 811 / 2254
# Finished composing for query number : 812 / 2254
# Finished composing for query number : 813 / 2254
# Finished composing for query number : 814 / 2254
# Finished composing for query number : 815 / 2254
# Finished composing for query number : 816 / 2254
# Finished composing for query number : 817 / 2254
# Finished composing for query number : 818 / 2254
# Finished composing for query number : 819 / 2254
# Finished composing for query number : 820 / 2254
# Finished composing for query number : 821 / 2254
# Finished composing for query number : 822 / 2254
# Finished composing for query number : 823 / 2254
# Finished composing for query number : 824 / 2254
# Finished composing for query number : 825 / 2254
# Finished composing for query number : 826 / 2254
# Finished composing for query number : 827 / 2254
# Finished composing for query number : 828 / 2254
# Finished composing for query number : 829 / 2254
# Finished composing for query number : 830 / 2254
# Finished composing for query number : 831 / 2254
# Finished composing for query number : 832 / 2254
# Finished composing for query number : 833 / 2254
# Finished composing for query number : 834 / 2254
# Finished composing for query number : 835 / 2254
# Finished composing for query number : 836 / 2254
# Finished composing for query number : 837 / 2254
# Finished composing for query number : 838 / 2254
# Finished composing for query number : 839 / 2254
# Finished composing for query number : 840 / 2254
# Finished composing for query number : 841 / 2254
# Finished composing for query number : 842 / 2254
# Finished composing for query number : 843 / 2254
# Finished composing for query number : 844 / 2254
# Finished composing for query number : 845 / 2254
# Finished composing for query number : 846 / 2254
# Finished composing for query number : 847 / 2254
# Finished composing for query number : 848 / 2254
# Finished composing for query number : 849 / 2254
# Finished composing for query number : 850 / 2254
# Finished composing for query number : 851 / 2254
# Finished composing for query number : 852 / 2254
# Finished composing for query number : 853 / 2254
# Finished composing for query number : 854 / 2254
# Finished composing for query number : 855 / 2254
# Finished composing for query number : 856 / 2254
# Finished composing for query number : 857 / 2254
# Finished composing for query number : 858 / 2254
# Finished composing for query number : 859 / 2254
# Finished composing for query number : 860 / 2254
# Finished composing for query number : 861 / 2254
# Finished composing for query number : 862 / 2254
# Finished composing for query number : 863 / 2254
# Finished composing for query number : 864 / 2254
# Finished composing for query number : 865 / 2254
# Finished composing for query number : 866 / 2254
# Finished composing for query number : 867 / 2254
# Finished composing for query number : 868 / 2254
# Finished composing for query number : 869 / 2254
# Finished composing for query number : 870 / 2254
# Finished composing for query number : 871 / 2254
# Finished composing for query number : 872 / 2254
# Finished composing for query number : 873 / 2254
# Finished composing for query number : 874 / 2254
# Finished composing for query number : 875 / 2254
# Finished composing for query number : 876 / 2254
# Finished composing for query number : 877 / 2254
# Finished composing for query number : 878 / 2254
# Finished composing for query number : 879 / 2254
# Finished composing for query number : 880 / 2254
# Finished composing for query number : 881 / 2254
# Finished composing for query number : 882 / 2254
# Finished composing for query number : 883 / 2254
# Finished composing for query number : 884 / 2254
# Finished composing for query number : 885 / 2254
# Finished composing for query number : 886 / 2254
# Finished composing for query number : 887 / 2254
# Finished composing for query number : 888 / 2254
# Finished composing for query number : 889 / 2254
# Finished composing for query number : 890 / 2254
# Finished composing for query number : 891 / 2254
# Finished composing for query number : 892 / 2254
# Finished composing for query number : 893 / 2254
# Finished composing for query number : 894 / 2254
# Finished composing for query number : 895 / 2254
# Finished composing for query number : 896 / 2254
# Finished composing for query number : 897 / 2254
# Finished composing for query number : 898 / 2254
# Finished composing for query number : 899 / 2254
# Finished composing for query number : 900 / 2254
# Finished composing for query number : 901 / 2254
# Finished composing for query number : 902 / 2254
# Finished composing for query number : 903 / 2254
# Finished composing for query number : 904 / 2254
# Finished composing for query number : 905 / 2254
# Finished composing for query number : 906 / 2254
# Finished composing for query number : 907 / 2254
# Finished composing for query number : 908 / 2254
# Finished composing for query number : 909 / 2254
# Finished composing for query number : 910 / 2254
# Finished composing for query number : 911 / 2254
# Finished composing for query number : 912 / 2254
# Finished composing for query number : 913 / 2254
# Finished composing for query number : 914 / 2254
# Finished composing for query number : 915 / 2254
# Finished composing for query number : 916 / 2254
# Finished composing for query number : 917 / 2254
# Finished composing for query number : 918 / 2254
# Finished composing for query number : 919 / 2254
# Finished composing for query number : 920 / 2254
# Finished composing for query number : 921 / 2254
# Finished composing for query number : 922 / 2254
# Finished composing for query number : 923 / 2254
# Finished composing for query number : 924 / 2254
# Finished composing for query number : 925 / 2254
# Finished composing for query number : 926 / 2254
# Finished composing for query number : 927 / 2254
# Finished composing for query number : 928 / 2254
# Finished composing for query number : 929 / 2254
# Finished composing for query number : 930 / 2254
# Finished composing for query number : 931 / 2254
# Finished composing for query number : 932 / 2254
# Finished composing for query number : 933 / 2254
# Finished composing for query number : 934 / 2254
# Finished composing for query number : 935 / 2254
# Finished composing for query number : 936 / 2254
# Finished composing for query number : 937 / 2254
# Finished composing for query number : 938 / 2254
# Finished composing for query number : 939 / 2254
# Finished composing for query number : 940 / 2254
# Finished composing for query number : 941 / 2254
# Finished composing for query number : 942 / 2254
# Finished composing for query number : 943 / 2254
# Finished composing for query number : 944 / 2254
# Finished composing for query number : 945 / 2254
# Finished composing for query number : 946 / 2254
# Finished composing for query number : 947 / 2254
# Finished composing for query number : 948 / 2254
# Finished composing for query number : 949 / 2254
# Finished composing for query number : 950 / 2254
# Finished composing for query number : 951 / 2254
# Finished composing for query number : 952 / 2254
# Finished composing for query number : 953 / 2254
# Finished composing for query number : 954 / 2254
# Finished composing for query number : 955 / 2254
# Finished composing for query number : 956 / 2254
# Finished composing for query number : 957 / 2254
# Finished composing for query number : 958 / 2254
# Finished composing for query number : 959 / 2254
# Finished composing for query number : 960 / 2254
# Finished composing for query number : 961 / 2254
# Finished composing for query number : 962 / 2254
# Finished composing for query number : 963 / 2254
# Finished composing for query number : 964 / 2254
# Finished composing for query number : 965 / 2254
# Finished composing for query number : 966 / 2254
# Finished composing for query number : 967 / 2254
# Finished composing for query number : 968 / 2254
# Finished composing for query number : 969 / 2254
# Finished composing for query number : 970 / 2254
# Finished composing for query number : 971 / 2254
# Finished composing for query number : 972 / 2254
# Finished composing for query number : 973 / 2254
# Finished composing for query number : 974 / 2254
# Finished composing for query number : 975 / 2254
# Finished composing for query number : 976 / 2254
# Finished composing for query number : 977 / 2254
# Finished composing for query number : 978 / 2254
# Finished composing for query number : 979 / 2254
# Finished composing for query number : 980 / 2254
# Finished composing for query number : 981 / 2254
# ...
# Finished composing for query number : 1937 / 2254
# Finished composing for query number : 1938 / 2254
# Finished composing for query number : 1939 / 2254
# Finished composing for query number : 1940 / 2254
# Finished composing for query number : 1941 / 2254
# Finished composing for query number : 1942 / 2254
# Finished composing for query number : 1943 / 2254
# Finished composing for query number : 1944 / 2254
# Finished composing for query number : 1945 / 2254
# Finished composing for query number : 1946 / 2254
# Finished composing for query number : 1947 / 2254
# Finished composing for query number : 1948 / 2254
# Finished composing for query number : 1949 / 2254
# Finished composing for query number : 1950 / 2254
# Finished composing for query number : 1951 / 2254
# Finished composing for query number : 1952 / 2254
# Finished composing for query number : 1953 / 2254
# Finished composing for query number : 1954 / 2254
# Finished composing for query number : 1955 / 2254
# Finished composing for query number : 1956 / 2254
# Finished composing for query number : 1957 / 2254
# Finished composing for query number : 1958 / 2254
# Finished composing for query number : 1959 / 2254
# Finished composing for query number : 1960 / 2254
# Finished composing for query number : 1961 / 2254
# Finished composing for query number : 1962 / 2254
# Finished composing for query number : 1963 / 2254
# Finished composing for query number : 1964 / 2254
# Finished composing for query number : 1965 / 2254
# Finished composing for query number : 1966 / 2254
# Finished composing for query number : 1967 / 2254
# Finished composing for query number : 1968 / 2254
# Finished composing for query number : 1969 / 2254
# Finished composing for query number : 1970 / 2254
# Finished composing for query number : 1971 / 2254
# Finished composing for query number : 1972 / 2254
# Finished composing for query number : 1973 / 2254
# Finished composing for query number : 1974 / 2254
# Finished composing for query number : 1975 / 2254
# Finished composing for query number : 1976 / 2254
# Finished composing for query number : 1977 / 2254
# Finished composing for query number : 1978 / 2254
# Finished composing for query number : 1979 / 2254
# Finished composing for query number : 1980 / 2254
# Finished composing for query number : 1981 / 2254
# Finished composing for query number : 1982 / 2254
# Finished composing for query number : 1983 / 2254
# Finished composing for query number : 1984 / 2254
# Finished composing for query number : 1985 / 2254
# Finished composing for query number : 1986 / 2254
# Finished composing for query number : 1987 / 2254
# Finished composing for query number : 1988 / 2254
# Finished composing for query number : 1989 / 2254
# Finished composing for query number : 1990 / 2254
# Finished composing for query number : 1991 / 2254
# Finished composing for query number : 1992 / 2254
# Finished composing for query number : 1993 / 2254
# Finished composing for query number : 1994 / 2254
# Finished composing for query number : 1995 / 2254
# Finished composing for query number : 1996 / 2254
# Finished composing for query number : 1997 / 2254
# Finished composing for query number : 1998 / 2254
# Finished composing for query number : 1999 / 2254
# Finished composing for query number : 2000 / 2254
# Finished composing for query number : 2001 / 2254
# Finished composing for query number : 2002 / 2254
# Finished composing for query number : 2003 / 2254
# Finished composing for query number : 2004 / 2254
# Finished composing for query number : 2005 / 2254
# Finished composing for query number : 2006 / 2254
# Finished composing for query number : 2007 / 2254
# Finished composing for query number : 2008 / 2254
# Finished composing for query number : 2009 / 2254
# Finished composing for query number : 2010 / 2254
# Finished composing for query number : 2011 / 2254
# Finished composing for query number : 2012 / 2254
# Finished composing for query number : 2013 / 2254
# Finished composing for query number : 2014 / 2254
# Finished composing for query number : 2015 / 2254
# Finished composing for query number : 2016 / 2254
# Finished composing for query number : 2017 / 2254
# Finished composing for query number : 2018 / 2254
# Finished composing for query number : 2019 / 2254
# Finished composing for query number : 2020 / 2254
# Finished composing for query number : 2021 / 2254
# Finished composing for query number : 2022 / 2254
# Finished composing for query number : 2023 / 2254
# Finished composing for query number : 2024 / 2254
# Finished composing for query number : 2025 / 2254
# Finished composing for query number : 2026 / 2254
# Finished composing for query number : 2027 / 2254
# Finished composing for query number : 2028 / 2254
# Finished composing for query number : 2029 / 2254
# Finished composing for query number : 2030 / 2254
# Finished composing for query number : 2031 / 2254
# Finished composing for query number : 2032 / 2254
# Finished composing for query number : 2033 / 2254
# Finished composing for query number : 2034 / 2254
# Finished composing for query number : 2035 / 2254
# Finished composing for query number : 2036 / 2254
# Finished composing for query number : 2037 / 2254
# Finished composing for query number : 2038 / 2254
# Finished composing for query number : 2039 / 2254
# Finished composing for query number : 2040 / 2254
# Finished composing for query number : 2041 / 2254
# Finished composing for query number : 2042 / 2254
# Finished composing for query number : 2043 / 2254
# Finished composing for query number : 2044 / 2254
# Finished composing for query number : 2045 / 2254
# Finished composing for query number : 2046 / 2254
# Finished composing for query number : 2047 / 2254
# Finished composing for query number : 2048 / 2254
# Finished composing for query number : 2049 / 2254
# Finished composing for query number : 2050 / 2254
# Finished composing for query number : 2051 / 2254
# Finished composing for query number : 2052 / 2254
# Finished composing for query number : 2053 / 2254
# Finished composing for query number : 2054 / 2254
# Finished composing for query number : 2055 / 2254
# Finished composing for query number : 2056 / 2254
# Finished composing for query number : 2057 / 2254
# Finished composing for query number : 2058 / 2254
# Finished composing for query number : 2059 / 2254
# Finished composing for query number : 2060 / 2254
# Finished composing for query number : 2061 / 2254
# Finished composing for query number : 2062 / 2254
# Finished composing for query number : 2063 / 2254
# Finished composing for query number : 2064 / 2254
# Finished composing for query number : 2065 / 2254
# Finished composing for query number : 2066 / 2254
# Finished composing for query number : 2067 / 2254
# Finished composing for query number : 2068 / 2254
# Finished composing for query number : 2069 / 2254
# Finished composing for query number : 2070 / 2254
# Finished composing for query number : 2071 / 2254
# Finished composing for query number : 2072 / 2254
# Finished composing for query number : 2073 / 2254
# Finished composing for query number : 2074 / 2254
# Finished composing for query number : 2075 / 2254
# Finished composing for query number : 2076 / 2254
# Finished composing for query number : 2077 / 2254
# Finished composing for query number : 2078 / 2254
# Finished composing for query number : 2079 / 2254
# Finished composing for query number : 2080 / 2254
# Finished composing for query number : 2081 / 2254
# Finished composing for query number : 2082 / 2254
# Finished composing for query number : 2083 / 2254
# Finished composing for query number : 2084 / 2254
# Finished composing for query number : 2085 / 2254
# Finished composing for query number : 2086 / 2254
# Finished composing for query number : 2087 / 2254
# Finished composing for query number : 2088 / 2254
# Finished composing for query number : 2089 / 2254
# Finished composing for query number : 2090 / 2254
# Finished composing for query number : 2091 / 2254
# Finished composing for query number : 2092 / 2254
# Finished composing for query number : 2093 / 2254
# Finished composing for query number : 2094 / 2254
# Finished composing for query number : 2095 / 2254
# Finished composing for query number : 2096 / 2254
# Finished composing for query number : 2097 / 2254
# Finished composing for query number : 2098 / 2254
# Finished composing for query number : 2099 / 2254
# Finished composing for query number : 2100 / 2254
# Finished composing for query number : 2101 / 2254
# Finished composing for query number : 2102 / 2254
# Finished composing for query number : 2103 / 2254
# Finished composing for query number : 2104 / 2254
# Finished composing for query number : 2105 / 2254
# Finished composing for query number : 2106 / 2254
# Finished composing for query number : 2107 / 2254
# Finished composing for query number : 2108 / 2254
# Finished composing for query number : 2109 / 2254
# Finished composing for query number : 2110 / 2254
# Finished composing for query number : 2111 / 2254
# Finished composing for query number : 2112 / 2254
# Finished composing for query number : 2113 / 2254
# Finished composing for query number : 2114 / 2254
# Finished composing for query number : 2115 / 2254
# Finished composing for query number : 2116 / 2254
# Finished composing for query number : 2117 / 2254
# Finished composing for query number : 2118 / 2254
# Finished composing for query number : 2119 / 2254
# Finished composing for query number : 2120 / 2254
# Finished composing for query number : 2121 / 2254
# Finished composing for query number : 2122 / 2254
# Finished composing for query number : 2123 / 2254
# Finished composing for query number : 2124 / 2254
# Finished composing for query number : 2125 / 2254
# Finished composing for query number : 2126 / 2254
# Finished composing for query number : 2127 / 2254
# Finished composing for query number : 2128 / 2254
# Finished composing for query number : 2129 / 2254
# Finished composing for query number : 2130 / 2254
# Finished composing for query number : 2131 / 2254
# Finished composing for query number : 2132 / 2254
# Finished composing for query number : 2133 / 2254
# Finished composing for query number : 2134 / 2254
# Finished composing for query number : 2135 / 2254
# Finished composing for query number : 2136 / 2254
# Finished composing for query number : 2137 / 2254
# Finished composing for query number : 2138 / 2254
# Finished composing for query number : 2139 / 2254
# Finished composing for query number : 2140 / 2254
# Finished composing for query number : 2141 / 2254
# Finished composing for query number : 2142 / 2254
# Finished composing for query number : 2143 / 2254
# Finished composing for query number : 2144 / 2254
# Finished composing for query number : 2145 / 2254
# Finished composing for query number : 2146 / 2254
# Finished composing for query number : 2147 / 2254
# Finished composing for query number : 2148 / 2254
# Finished composing for query number : 2149 / 2254
# Finished composing for query number : 2150 / 2254
# Finished composing for query number : 2151 / 2254
# Finished composing for query number : 2152 / 2254
# Finished composing for query number : 2153 / 2254
# Finished composing for query number : 2154 / 2254
# Finished composing for query number : 2155 / 2254
# Finished composing for query number : 2156 / 2254
# Finished composing for query number : 2157 / 2254
# Finished composing for query number : 2158 / 2254
# Finished composing for query number : 2159 / 2254
# Finished composing for query number : 2160 / 2254
# Finished composing for query number : 2161 / 2254
# Finished composing for query number : 2162 / 2254
# Finished composing for query number : 2163 / 2254
# Finished composing for query number : 2164 / 2254
# Finished composing for query number : 2165 / 2254
# Finished composing for query number : 2166 / 2254
# Finished composing for query number : 2167 / 2254
# Finished composing for query number : 2168 / 2254
# Finished composing for query number : 2169 / 2254
# Finished composing for query number : 2170 / 2254
# Finished composing for query number : 2171 / 2254
# Finished composing for query number : 2172 / 2254
# Finished composing for query number : 2173 / 2254
# Finished composing for query number : 2174 / 2254
# Finished composing for query number : 2175 / 2254
# Finished composing for query number : 2176 / 2254
# Finished composing for query number : 2177 / 2254
# Finished composing for query number : 2178 / 2254
# Finished composing for query number : 2179 / 2254
# Finished composing for query number : 2180 / 2254
# Finished composing for query number : 2181 / 2254
# Finished composing for query number : 2182 / 2254
# Finished composing for query number : 2183 / 2254
# Finished composing for query number : 2184 / 2254
# Finished composing for query number : 2185 / 2254
# Finished composing for query number : 2186 / 2254
# Finished composing for query number : 2187 / 2254
# Finished composing for query number : 2188 / 2254
# Finished composing for query number : 2189 / 2254
# Finished composing for query number : 2190 / 2254
# Finished composing for query number : 2191 / 2254
# Finished composing for query number : 2192 / 2254
# Finished composing for query number : 2193 / 2254
# Finished composing for query number : 2194 / 2254
# Finished composing for query number : 2195 / 2254
# Finished composing for query number : 2196 / 2254
# Finished composing for query number : 2197 / 2254
# Finished composing for query number : 2198 / 2254
# Finished composing for query number : 2199 / 2254
# Finished composing for query number : 2200 / 2254
# Finished composing for query number : 2201 / 2254
# Finished composing for query number : 2202 / 2254
# Finished composing for query number : 2203 / 2254
# Finished composing for query number : 2204 / 2254
# Finished composing for query number : 2205 / 2254
# Finished composing for query number : 2206 / 2254
# Finished composing for query number : 2207 / 2254
# Finished composing for query number : 2208 / 2254
# Finished composing for query number : 2209 / 2254
# Finished composing for query number : 2210 / 2254
# Finished composing for query number : 2211 / 2254
# Finished composing for query number : 2212 / 2254
# Finished composing for query number : 2213 / 2254
# Finished composing for query number : 2214 / 2254
# Finished composing for query number : 2215 / 2254
# Finished composing for query number : 2216 / 2254
# Finished composing for query number : 2217 / 2254
# Finished composing for query number : 2218 / 2254
# Finished composing for query number : 2219 / 2254
# Finished composing for query number : 2220 / 2254
# Finished composing for query number : 2221 / 2254
# Finished composing for query number : 2222 / 2254
# Finished composing for query number : 2223 / 2254
# Finished composing for query number : 2224 / 2254
# Finished composing for query number : 2225 / 2254
# Finished composing for query number : 2226 / 2254
# Finished composing for query number : 2227 / 2254
# Finished composing for query number : 2228 / 2254
# Finished composing for query number : 2229 / 2254
# Finished composing for query number : 2230 / 2254
# Finished composing for query number : 2231 / 2254
# Finished composing for query number : 2232 / 2254
# Finished composing for query number : 2233 / 2254
# Finished composing for query number : 2234 / 2254
# Finished composing for query number : 2235 / 2254
# Finished composing for query number : 2236 / 2254
# Finished composing for query number : 2237 / 2254
# Finished composing for query number : 2238 / 2254
# Finished composing for query number : 2239 / 2254
# Finished composing for query number : 2240 / 2254
# Finished composing for query number : 2241 / 2254
# Finished composing for query number : 2242 / 2254
# Finished composing for query number : 2243 / 2254
# Finished composing for query number : 2244 / 2254
# Finished composing for query number : 2245 / 2254
# Finished composing for query number : 2246 / 2254
# Finished composing for query number : 2247 / 2254
# Finished composing for query number : 2248 / 2254
# Finished composing for query number : 2249 / 2254
# Finished composing for query number : 2250 / 2254
# Finished composing for query number : 2251 / 2254
# Finished composing for query number : 2252 / 2254
# Finished composing for query number : 2253 / 2254
# Finished composing for query number : 2254 / 2254
#
# Missing query-doc pairs :  5
# Done train, val, and test !!!

# %%
! ls exp1_sim
# Out:
# ranked.test.relevance.txt

# %%
! ../Eval/trec_eval-master/trec_eval ../Eval/qrelsY1-test.V2.0/automatic-test.pages.cbor-hierarchical.qrels exp1_sim/ranked.test.relevance.txt -m all_trec
# > exp1_sim_trec_results_withTestVocab.txt
# Out:
# runid                 	all	rchan31
# num_q                 	all	2254
# num_ret               	all	225156
# num_rel               	all	6192
# num_rel_ret           	all	2375
# map                   	all	0.0670
# gm_map                	all	0.0025
# Rprec                 	all	0.0395
# bpref                 	all	0.4689
# recip_rank            	all	0.1058
# iprec_at_recall_0.00  	all	0.1086
# iprec_at_recall_0.10  	all	0.1082
# iprec_at_recall_0.20  	all	0.1006
# iprec_at_recall_0.30  	all	0.0866
# iprec_at_recall_0.40  	all	0.0720
# iprec_at_recall_0.50  	all	0.0692
# iprec_at_recall_0.60  	all	0.0500
# iprec_at_recall_0.70  	all	0.0486
# iprec_at_recall_0.80  	all	0.0439
# iprec_at_recall_0.90  	all	0.0433
# iprec_at_recall_1.00  	all	0.0433
# P_5                   	all	0.0307
# P_10                  	all	0.0255
# P_15                  	all	0.0219
# P_20                  	all	0.0197
# P_30                  	all	0.0171
# P_100                 	all	0.0105
# P_200                 	all	0.0053
# P_500                 	all	0.0021
# P_1000                	all	0.0011
# recall_5              	all	0.0808
# recall_10             	all	0.1282
# recall_15             	all	0.1636
# recall_20             	all	0.1948
# recall_30             	all	0.2451
# recall_100            	all	0.4689
# recall_200            	all	0.4689
# recall_500            	all	0.4689
# recall_1000           	all	0.4689
# infAP                 	all	0.0670
# gm_bpref              	all	0.0171
# Rprec_mult_0.20       	all	0.0458
# Rprec_mult_0.40       	all	0.0433
# Rprec_mult_0.60       	all	0.0413
# Rprec_mult_0.80       	all	0.0402
# Rprec_mult_1.00       	all	0.0395
# Rprec_mult_1.20       	all	0.0353
# Rprec_mult_1.40       	all	0.0350
# Rprec_mult_1.60       	all	0.0345
# Rprec_mult_1.80       	all	0.0346
# Rprec_mult_2.00       	all	0.0343
# utility               	all	-97.7844
# 11pt_avg              	all	0.0704
# binG                  	all	0.1357
# G                     	all	0.1357
# ndcg                  	all	0.1631
# ndcg_rel              	all	0.1572
# Rndcg                 	all	0.1021
# ndcg_cut_5            	all	0.0635
# ndcg_cut_10           	all	0.0814
# ndcg_cut_15           	all	0.0926
# ndcg_cut_20           	all	0.1015
# ndcg_cut_30           	all	0.1148
# ndcg_cut_100          	all	0.1631
# ndcg_cut_200          	all	0.1631
# ndcg_cut_500          	all	0.1631
# ndcg_cut_1000         	all	0.1631
# map_cut_5             	all	0.0460
# map_cut_10            	all	0.0534
# map_cut_15            	all	0.0567
# map_cut_20            	all	0.0587
# map_cut_30            	all	0.0612
# map_cut_100           	all	0.0670
# map_cut_200           	all	0.0670
# map_cut_500           	all	0.0670
# map_cut_1000          	all	0.0670
# relative_P_5          	all	0.0818
# relative_P_10         	all	0.1283
# relative_P_15         	all	0.1636
# relative_P_20         	all	0.1948
# relative_P_30         	all	0.2451
# relative_P_100        	all	0.4689
# relative_P_200        	all	0.4689
# relative_P_500        	all	0.4689
# relative_P_1000       	all	0.4689
# success_1             	all	0.0470
# success_5             	all	0.1415
# success_10            	all	0.2205
# set_P                 	all	0.0106
# set_relative_P        	all	0.4689
# set_recall            	all	0.4689
# set_map               	all	0.0075
# set_F                 	all	0.0204
# num_nonrel_judged_ret 	all	0

# %%
! ../Eval/trec_eval-master/trec_eval ../Eval/qrelsY1-test.V2.0/automatic-test.pages.cbor-hierarchical.qrels exp1_sim/ranked.test.relevance.txt  -m all_trec > exp1_sim_trec_results_withTestVocab.txt
