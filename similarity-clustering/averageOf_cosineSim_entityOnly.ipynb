# %%
import pandas as pd
import numpy as np
import os
import glob
import json
import re
from collections import defaultdict

import torchtext
from torchtext.legacy.data import Example

from wikipedia2vec import Wikipedia2Vec

# %%
# Data with Entities

ROOT_FOLDER = "/raid6/home/ramraj/2021/ir/entity-reranking/Entity-Linking/"

# BENCHMARK_TRAIN_FOLD_FOLDER = os.path.join(ROOT_FOLDER, "benchmark-train-relevance-v2.0")
# BENCHMARK_TEST_FILE = os.path.join(ROOT_FOLDER, "test-data", "ramraj-test-data-top100-BM25.json")
BENCHMARK_TRAIN_FOLD_FOLDER = os.path.join(ROOT_FOLDER, "Train-with-entities")
BENCHMARK_TEST_FILE = os.path.join(ROOT_FOLDER, "Test-with-entities/ramraj-test-data-top100-BM25-opt.json")

# BENCHMARK_TRAIN_FOLD_FOLDER = os.path.join(ROOT_FOLDER, "Train-with-entities-sepEntAndWords")
# BENCHMARK_TEST_FILE = os.path.join(ROOT_FOLDER, "Test-with-entities/ramraj-test-data-top100-BM25-opt-entWordSEP.json")

# %% [markdown]
# # laod train

# %%
train_files = sorted(glob.glob(os.path.join(BENCHMARK_TRAIN_FOLD_FOLDER, "fold-*.json")))
print( len(train_files) )

train_data = []
for train_file in train_files:
    tmp_data = json.load(open(train_file, 'r'))
    train_data.extend(tmp_data)
    
len(train_data)
# Out:
# 5
# 1937

# %% [markdown]
# # load test

# %%
test_data = json.load(open(BENCHMARK_TEST_FILE, 'r'))
len(test_data)
# Out:
# 2254

# %% [markdown]
# # utils

# %%
# def tokenise(text):
#     # Replace annoying unicode with a space
#     text = re.sub(r'[^\x00-\x7F]+', ' ', text)
#     # The following replacements are suggested in the paper
#     # BidAF (Seo et al., 2016)
#     text = text.replace("''", '" ')
#     text = text.replace("``", '" ')

#     # Space out punctuation
#     space_list = "!\"#$%&()*+,-./:;<=>?@[\\]^_`{|}~"
#     space_list = "!\"#$%&()*+,./:;<=>?@[\\]^_`{|}~"
#     text = text.translate(str.maketrans({key: " {0} ".format(key) for key in space_list}))

#     # space out singlequotes a bit better (and like stanford)
#     text = text.replace("'", " '")
    
#     # use any APIs
#     text = text.replace('\t', '').replace('\n', '').lower().strip()
#     return text

# %%
def alpha_numeric_filtering(text):
    regex = re.compile('[^a-zA-Z]')
    #First parameter is the replacement, second parameter is your input string
    return regex.sub(' ', text)

# %% [markdown]
# # load wikie

# %%
import torchtext.vocab as vocab

MODEL_FILE = "../entity-embedding-modelling/data/enwiki_20180420_300d.txt"
# https://github.com/pytorch/text/issues/722

custom_embeddings = vocab.Vectors(name = MODEL_FILE, cache="/raid6/home/ramraj/2021/ir/entity-reranking/entity-embedding-modelling/data/cache-enwiki")

# %%
# PKL_MODEL_FILE = "../entity-embedding-modelling/data/enwiki_20180420_100d.pkl"
# wiki2vec = Wikipedia2Vec.load(PKL_MODEL_FILE)

# %% [markdown]
# # vocab

# %%
PAD_TOKEN = '<PAD>'
SOS_TOKEN = '<SOS>'
UNK_TOKEN = '<UNK>'
EOS_TOKEN = '<EOS>'

MAX_Q_LENGTH = 20
MAX_D_LEN = 200

Q_TEXT = torchtext.legacy.data.Field(sequential=True, 
                                tokenize=lambda x: x.split('<SEP>'),
                                eos_token=EOS_TOKEN,
                                pad_token=PAD_TOKEN,
                                include_lengths=True,
                                batch_first=True,
                                fix_length=MAX_Q_LENGTH,
                                lower=True)

DOC_TEXT = torchtext.legacy.data.Field(sequential=True, 
                                tokenize=lambda x: x.split('<SEP>'),
                                eos_token=EOS_TOKEN,
                                pad_token=PAD_TOKEN,
                                include_lengths=True,
                                batch_first=True,
                                fix_length=MAX_D_LEN,
                                lower=True)

# %%
example_texts = []

FIELDS = [('doc_text', DOC_TEXT), ('q_text', Q_TEXT)]
# https://github.com/pytorch/text/issues/722


for train_data_sample in train_data:
    # q_text = train_data_sample['qString']
    q_text = '<SEP>'.join( [ e['entity_title'] for e in train_data_sample['qEntities'] ] )
    
    for rel_docs in train_data_sample['RelevantDocuments']:
        # doc_text = rel_docs['docText']
        # dEntities = [ e['entity_title'] for e in rel_docs['dEntities'] ]
        doc_text = '<SEP>'.join( [ e['entity_title'] for e in rel_docs['dEntities'] ] )

        
        example_texts.append( Example.fromlist([doc_text, q_text] , FIELDS ) )
        
for test_data_sample in test_data:
    # q_text = test_data_sample['qString']
    q_text = '<SEP>'.join( [ e['entity_title'] for e in test_data_sample['qEntities'] ] )
    
    for rel_docs in test_data_sample['RelevantDocuments']:
        # doc_text = rel_docs['docText']
        doc_text = '<SEP>'.join( [ e['entity_title'] for e in rel_docs['dEntities'] ] )
        
        example_texts.append( Example.fromlist([doc_text, q_text] , FIELDS ) )

# %%
torchtext_dataset = torchtext.legacy.data.Dataset(example_texts, fields=FIELDS)

Q_TEXT.build_vocab(torchtext_dataset, vectors=custom_embeddings, vectors_cache="/raid6/home/ramraj/2021/ir/entity-reranking/entity-embedding-modelling/data/cache-enwiki")
DOC_TEXT.build_vocab(torchtext_dataset, vectors=custom_embeddings, vectors_cache="/raid6/home/ramraj/2021/ir/entity-reranking/entity-embedding-modelling/data/cache-enwiki")

print("======= Query ========")
print(len(Q_TEXT.vocab) )
print(Q_TEXT.vocab.vectors.size() )
print("======= Doc ========")
print( len(DOC_TEXT.vocab))
print( DOC_TEXT.vocab.vectors.size())
# Out:
# ======= Query ========
# 2943
# torch.Size([2943, 300])
# ======= Doc ========
# 171341
# torch.Size([171341, 300])

# %%
print( DOC_TEXT.vocab.stoi['university of southampton'], DOC_TEXT.vocab.itos[14] )
print( DOC_TEXT.vocab.stoi['fahrenheit'], DOC_TEXT.vocab.itos[3] )
# Out:
# 11557 disease
# 9974 human trafficking

# %% [markdown]
# # dataset

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch

from pytorch_transformers import WarmupLinearSchedule, AdamW
from transformers import get_linear_schedule_with_warmup

def map_to_torch_float(encoding):
    encoding = torch.FloatTensor(encoding)
    encoding.requires_grad_(False)
    return encoding

def map_to_torch(encoding):
    encoding = torch.LongTensor(encoding)
    encoding.requires_grad_(False)
    return encoding


class TestTRECDataset(Dataset):
    def __init__(self, raw_data, q_field, d_field, query_max_len=20, max_len=512, is_train=True):
        self.is_train = is_train
        self.max_len = max_len
        self.query_max_len = query_max_len
        
        self.q_field = q_field
        self.d_field = d_field

        self.qLookup = defaultdict()
        self.dLookup = defaultdict()
        self.data_df = self.load_data(raw_data)
        self.len = len(self.data_df)
        
    def load_data(self, data):
        return_data = {'qID': [], 'qText': [], 'dID': [], 'dText': [], 'label': []}
        for data_sample in data:
            qID = data_sample['qID']
            # qText = data_sample['qString']
            qText = '<SEP>'.join( [ e['entity_title'] for e in data_sample['qEntities'] ] )

            if qText == '': continue
            self.qLookup[qID] = qText

            for rel_docs in data_sample['RelevantDocuments']:
                dID = rel_docs['docID']
                # docText = rel_docs['docText']
                docText = '<SEP>'.join( [ e['entity_title'] for e in rel_docs['dEntities'] ] )
                
                if docText == '': continue
                self.dLookup[dID] = docText

                return_data['qID'].append(qID)
                return_data['dID'].append(dID)
                # return_data['qText'].append( qText )
                # return_data['dText'].append( docText )

        # df = pd.DataFrame(return_data, columns=["qID", "qText", "dID", "dText"])
        df = pd.DataFrame(return_data, columns=["qID", "dID"])
        return df
    
    def __len__(self):
        return self.len
    
    def __getitem__(self, index):
        index = index % self.len
        inst = self.data_df.loc[index]
        docID = inst['dID']
        qID = inst['qID']
        docText = self.dLookup[docID] # self.dLookup[docID] # inst['dText']
        qText = self.qLookup[qID] # self.qLookup[qID] # inst['qText']
        
        # print(qID)
        # print(qText)
        # print()
        # print(docID)
        # print(docText)

        # =============== prepare text before feed ===============
        q_text_processed = self.q_field.numericalize( self.q_field.pad([ [l for l in self.q_field.preprocess(qText) if l.strip()] ]) )
        d_text_processed = self.d_field.numericalize( self.d_field.pad([ [l for l in self.d_field.preprocess(docText) if l.strip()] ]) )

        return q_text_processed, d_text_processed, qID, docID
    

test_trec_dataset = TestTRECDataset(test_data, Q_TEXT, DOC_TEXT)
print( test_trec_dataset.__len__() )

q, d, qID, dID = test_trec_dataset.__getitem__(1)

print(q[0].shape)
print(d[0].shape)
# print(q[0][0].shape)
# print(out[1][0].shape)
# print(out[2][0].shape)
# print()
# print(out[0][0].shape)
# Out:
# 223331
# torch.Size([1, 20])
# torch.Size([1, 200])

# %%
q_str = []
for qq in q[0][0]:
    q_str.append(Q_TEXT.vocab.itos[qq])
print(' '.join( q_str) )
print()

q_str = []
for qq in d[0][0]:
    q_str.append(DOC_TEXT.vocab.itos[qq])
print(' '.join( q_str) )
print()
# Out:
# aftertaste <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
#
# aftertaste food drink perception food drink mouth food drink tin can aftertaste perception food drink neuroscience evolution aftertaste signal transduction taste receptor adrenergic receptor mouth brain food processing insular cortex aftertaste perception <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# # Model

# %%
import typing
import torch.nn as nn
import torch.nn.functional as F


class SimScorer(nn.Module):
    def __init__(self, q_text_field, d_text_field, with_multi_layer_perceptron=True, mlp_num_layers=2, mlp_num_units=300, mlp_num_fan_out=1, padding_idx=1, embedding_freeze=True):
        super(SimScorer, self).__init__()
        self.with_multi_layer_perceptron = with_multi_layer_perceptron

        self.mlp_num_layers = mlp_num_layers
        self.mlp_num_units = mlp_num_units
        self.mlp_num_fan_out = mlp_num_fan_out
        self.q_text_field = q_text_field
        self.d_text_field = d_text_field
        self.padding_idx = padding_idx
        self.embedding_freeze = embedding_freeze
        self.build()
            
    def build(self):
        """
        Build model structure.
        """
        self.q_embedding = nn.Embedding.from_pretrained(self.q_text_field.vocab.vectors, padding_idx=self.padding_idx, freeze=self.embedding_freeze)
        self.d_embedding = nn.Embedding.from_pretrained(self.d_text_field.vocab.vectors, padding_idx=self.padding_idx, freeze=self.embedding_freeze)

    def forward(self, inputs):
        input_left, input_right = inputs['text_left'], inputs['text_right']
        
        input_left_emb = self.q_embedding(input_left)
        input_right_emb = self.d_embedding(input_right)
        
        # print("input_left_emb : ", input_left_emb.shape)
        # print("input_right_emb : ", input_right_emb.shape)
        
        input_left_emb_avg = torch.mean(input_left_emb, dim=1)
        input_right_emb_avg = torch.mean(input_right_emb, dim=1)
        
        # print("input_left_emb_avg : ", input_left_emb_avg.shape)
        # print("input_right_emb_avg : ", input_right_emb_avg.shape)
    
        # Dot product with cosine similarity.
        x = F.cosine_similarity(input_left_emb_avg, input_right_emb_avg)
        # x = x.unsqueeze(dim=1)
        # print("x : ", x.shape)

        return x


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

net = SimScorer(Q_TEXT, DOC_TEXT)
net.to(device)
print('Models built and ready to go!')

# tmp_q_text = torch.randint(low=1, high=30, size=(16, 20))
# tmp_d_text = torch.randint(low=1, high=30, size=(16, 200))
# print(tmp_q_text.shape)
# print(tmp_d_text.shape)

# input_text = {'text_left': tmp_q_text, 'text_right': tmp_d_text}

# output = net.forward(input_text)
# print(output)
# output.shape
# Out:
# cuda
# Models built and ready to go!

# %%
# import config
import random
from bunch import Bunch
import time
import datetime

CONFIG_FILE = "config.json"

def format_time(elapsed_time):
    """
    Takes a time in seconds and returns a string hh:mm:ss
    """
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed_time)))
    return str(datetime.timedelta(seconds=elapsed_rounded)) # Format as hh:mm:ss

def get_config_from_json(json_file):
    """
        Get the config from a json file
        :param json_file:
        :return: config(namespace) or config(dictionary)
        """
    # parse the configurations from the config json file provided
    with open(json_file, 'r') as config_file:
        config_dict = json.load(config_file)

    # convert the dictionary to a namespace using bunch lib
    config = Bunch(config_dict)

    return config, config_dict

import torch
config, _ = get_config_from_json(CONFIG_FILE)
seed_val = config.cmd_args['seed']
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)


config.data['results_dir'] = 'exp2_averageOf_cosineSim_entityOnly'



os.makedirs(config.data['results_dir'], exist_ok=True)

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# print(device)


test_dataloader = DataLoader(dataset=test_trec_dataset,
                              batch_size=config.training["test_batch_size"],
                              pin_memory=device,
                              num_workers=config.training['num_workers'],
                              shuffle=True)
n_test_batches = len(test_dataloader)
print("Number of test batches : ", n_test_batches)
net.eval()
# Out:
# Number of test batches :  873
# SimScorer(
#   (q_embedding): Embedding(2943, 300, padding_idx=1)
#   (d_embedding): Embedding(171341, 300, padding_idx=1)
# )

# %% [markdown]
# # test

# %%
qID_list = []
paraID_list = []
pScore_list = []
t1 = time.time()
for batch_idx, test_batch_data in enumerate(test_dataloader):
    # Converting these to cuda tensors
    q_text, d_text, qID, passageID = test_batch_data
#     print(type(q_text))
#     x = q_text[0]
#     y = q_text[1]
#     print(x.shape)
#     print(y.shape)
#     break
    q_text, d_text = torch.squeeze(q_text[0].to(device)), torch.squeeze(d_text[0]).to(device)

    with torch.no_grad():
        net_output = net({'text_left': q_text, 'text_right': d_text})
        net_output = net_output.detach().cpu().numpy()

        for i in range(len(qID)):
            qID_list.append(qID[i])
            paraID_list.append(passageID[i])
            pScore_list.append(net_output[i])
    elapsed = format_time(time.time() - t1)
    if batch_idx % 50 == 0:
        print('  Batch {:>5,}  of  {:>5,}  :  processed    Elapsed: {:}.'.format(batch_idx,
                                                                                 n_test_batches,
                                                                                 elapsed))

pScore_list = [float(e) for e in pScore_list]
predicted_df = pd.DataFrame({"qID": qID_list,
                             "pID": paraID_list,
                             "pScore": pScore_list}, columns=["qID", "pID", "pScore"])
if not config.cmd_args['mode'] == "experiment":
    predicted_df.to_csv(os.path.join(config.data['results_dir'], "predictions.csv"))
print()
# Out:
#   Batch     0  of    873  :  processed    Elapsed: 0:00:00.
#   Batch    50  of    873  :  processed    Elapsed: 0:00:07.
#   Batch   100  of    873  :  processed    Elapsed: 0:00:12.
#   Batch   150  of    873  :  processed    Elapsed: 0:00:18.
#   Batch   200  of    873  :  processed    Elapsed: 0:00:24.
#   Batch   250  of    873  :  processed    Elapsed: 0:00:29.
#   Batch   300  of    873  :  processed    Elapsed: 0:00:35.
#   Batch   350  of    873  :  processed    Elapsed: 0:00:41.
#   Batch   400  of    873  :  processed    Elapsed: 0:00:46.
#   Batch   450  of    873  :  processed    Elapsed: 0:00:52.
#   Batch   500  of    873  :  processed    Elapsed: 0:00:57.
#   Batch   550  of    873  :  processed    Elapsed: 0:01:03.
#   Batch   600  of    873  :  processed    Elapsed: 0:01:12.
#   Batch   650  of    873  :  processed    Elapsed: 0:01:17.
#   Batch   700  of    873  :  processed    Elapsed: 0:01:22.
#   Batch   750  of    873  :  processed    Elapsed: 0:01:29.
#   Batch   800  of    873  :  processed    Elapsed: 0:01:35.
#   Batch   850  of    873  :  processed    Elapsed: 0:01:41.

# %%
# ================================================
#               Reverse Sorting Relevance
# ================================================
predicted_df = predicted_df[['qID', 'pID', 'pScore']]
grouped_pred_df = predicted_df.groupby(["qID"])
num_queries = len(grouped_pred_df)
missing_q_sets = 0
save_ranked_file = os.path.join(config.data['results_dir'], "ranked.test.relevance.txt")
with open(save_ranked_file, 'w') as write_file:
    q_cnt = 1
    for name, row_group in grouped_pred_df:
        rank_cnt = 1

        # ======= SORTING =======
        sorted_row_group = row_group.sort_values(by='pScore', ascending=False, inplace=False)
        # =======================

        if len(sorted_row_group) != 100:
            # print(">>>>>>>>>>> Missing query %s with shape %s" % (name, sorted_row_group.shape))
            # print(">>>>>>>>>>> Missing query with size %s" % sorted_row_group.shape[0])
            missing_q_sets += 1

        for i, row in sorted_row_group.iterrows():
            write_file.write("%s\tQ0\t%s\t%s\t%s\trchan31\n" % \
                             (row["qID"], row["pID"], rank_cnt, row["pScore"]))
            rank_cnt += 1

        print("Finished composing for query number : %s / %s" % (q_cnt, num_queries))
        q_cnt += 1
print()
print("Missing query-doc pairs : ", missing_q_sets)
print("Done train, val, and test !!!")
# Out:
# Finished composing for query number : 1 / 2236
# Finished composing for query number : 2 / 2236
# Finished composing for query number : 3 / 2236
# Finished composing for query number : 4 / 2236
# Finished composing for query number : 5 / 2236
# Finished composing for query number : 6 / 2236
# Finished composing for query number : 7 / 2236
# Finished composing for query number : 8 / 2236
# Finished composing for query number : 9 / 2236
# Finished composing for query number : 10 / 2236
# Finished composing for query number : 11 / 2236
# Finished composing for query number : 12 / 2236
# Finished composing for query number : 13 / 2236
# Finished composing for query number : 14 / 2236
# Finished composing for query number : 15 / 2236
# Finished composing for query number : 16 / 2236
# Finished composing for query number : 17 / 2236
# Finished composing for query number : 18 / 2236
# Finished composing for query number : 19 / 2236
# Finished composing for query number : 20 / 2236
# Finished composing for query number : 21 / 2236
# Finished composing for query number : 22 / 2236
# Finished composing for query number : 23 / 2236
# Finished composing for query number : 24 / 2236
# Finished composing for query number : 25 / 2236
# Finished composing for query number : 26 / 2236
# Finished composing for query number : 27 / 2236
# Finished composing for query number : 28 / 2236
# Finished composing for query number : 29 / 2236
# Finished composing for query number : 30 / 2236
# Finished composing for query number : 31 / 2236
# Finished composing for query number : 32 / 2236
# Finished composing for query number : 33 / 2236
# Finished composing for query number : 34 / 2236
# Finished composing for query number : 35 / 2236
# Finished composing for query number : 36 / 2236
# Finished composing for query number : 37 / 2236
# Finished composing for query number : 38 / 2236
# Finished composing for query number : 39 / 2236
# Finished composing for query number : 40 / 2236
# Finished composing for query number : 41 / 2236
# Finished composing for query number : 42 / 2236
# Finished composing for query number : 43 / 2236
# Finished composing for query number : 44 / 2236
# Finished composing for query number : 45 / 2236
# Finished composing for query number : 46 / 2236
# Finished composing for query number : 47 / 2236
# Finished composing for query number : 48 / 2236
# Finished composing for query number : 49 / 2236
# Finished composing for query number : 50 / 2236
# Finished composing for query number : 51 / 2236
# Finished composing for query number : 52 / 2236
# Finished composing for query number : 53 / 2236
# Finished composing for query number : 54 / 2236
# Finished composing for query number : 55 / 2236
# Finished composing for query number : 56 / 2236
# Finished composing for query number : 57 / 2236
# Finished composing for query number : 58 / 2236
# Finished composing for query number : 59 / 2236
# Finished composing for query number : 60 / 2236
# Finished composing for query number : 61 / 2236
# Finished composing for query number : 62 / 2236
# Finished composing for query number : 63 / 2236
# Finished composing for query number : 64 / 2236
# Finished composing for query number : 65 / 2236
# Finished composing for query number : 66 / 2236
# Finished composing for query number : 67 / 2236
# Finished composing for query number : 68 / 2236
# Finished composing for query number : 69 / 2236
# Finished composing for query number : 70 / 2236
# Finished composing for query number : 71 / 2236
# Finished composing for query number : 72 / 2236
# Finished composing for query number : 73 / 2236
# Finished composing for query number : 74 / 2236
# Finished composing for query number : 75 / 2236
# Finished composing for query number : 76 / 2236
# Finished composing for query number : 77 / 2236
# Finished composing for query number : 78 / 2236
# Finished composing for query number : 79 / 2236
# Finished composing for query number : 80 / 2236
# Finished composing for query number : 81 / 2236
# Finished composing for query number : 82 / 2236
# Finished composing for query number : 83 / 2236
# Finished composing for query number : 84 / 2236
# Finished composing for query number : 85 / 2236
# Finished composing for query number : 86 / 2236
# Finished composing for query number : 87 / 2236
# Finished composing for query number : 88 / 2236
# Finished composing for query number : 89 / 2236
# Finished composing for query number : 90 / 2236
# Finished composing for query number : 91 / 2236
# Finished composing for query number : 92 / 2236
# Finished composing for query number : 93 / 2236
# Finished composing for query number : 94 / 2236
# Finished composing for query number : 95 / 2236
# Finished composing for query number : 96 / 2236
# Finished composing for query number : 97 / 2236
# Finished composing for query number : 98 / 2236
# Finished composing for query number : 99 / 2236
# Finished composing for query number : 100 / 2236
# Finished composing for query number : 101 / 2236
# Finished composing for query number : 102 / 2236
# Finished composing for query number : 103 / 2236
# Finished composing for query number : 104 / 2236
# Finished composing for query number : 105 / 2236
# Finished composing for query number : 106 / 2236
# Finished composing for query number : 107 / 2236
# Finished composing for query number : 108 / 2236
# Finished composing for query number : 109 / 2236
# Finished composing for query number : 110 / 2236
# Finished composing for query number : 111 / 2236
# Finished composing for query number : 112 / 2236
# Finished composing for query number : 113 / 2236
# Finished composing for query number : 114 / 2236
# Finished composing for query number : 115 / 2236
# Finished composing for query number : 116 / 2236
# Finished composing for query number : 117 / 2236
# Finished composing for query number : 118 / 2236
# Finished composing for query number : 119 / 2236
# Finished composing for query number : 120 / 2236
# Finished composing for query number : 121 / 2236
# Finished composing for query number : 122 / 2236
# Finished composing for query number : 123 / 2236
# Finished composing for query number : 124 / 2236
# Finished composing for query number : 125 / 2236
# Finished composing for query number : 126 / 2236
# Finished composing for query number : 127 / 2236
# Finished composing for query number : 128 / 2236
# Finished composing for query number : 129 / 2236
# Finished composing for query number : 130 / 2236
# Finished composing for query number : 131 / 2236
# Finished composing for query number : 132 / 2236
# Finished composing for query number : 133 / 2236
# Finished composing for query number : 134 / 2236
# Finished composing for query number : 135 / 2236
# Finished composing for query number : 136 / 2236
# Finished composing for query number : 137 / 2236
# Finished composing for query number : 138 / 2236
# Finished composing for query number : 139 / 2236
# Finished composing for query number : 140 / 2236
# Finished composing for query number : 141 / 2236
# Finished composing for query number : 142 / 2236
# Finished composing for query number : 143 / 2236
# Finished composing for query number : 144 / 2236
# Finished composing for query number : 145 / 2236
# Finished composing for query number : 146 / 2236
# Finished composing for query number : 147 / 2236
# Finished composing for query number : 148 / 2236
# Finished composing for query number : 149 / 2236
# Finished composing for query number : 150 / 2236
# Finished composing for query number : 151 / 2236
# Finished composing for query number : 152 / 2236
# Finished composing for query number : 153 / 2236
# Finished composing for query number : 154 / 2236
# Finished composing for query number : 155 / 2236
# Finished composing for query number : 156 / 2236
# Finished composing for query number : 157 / 2236
# Finished composing for query number : 158 / 2236
# Finished composing for query number : 159 / 2236
# Finished composing for query number : 160 / 2236
# Finished composing for query number : 161 / 2236
# Finished composing for query number : 162 / 2236
# Finished composing for query number : 163 / 2236
# Finished composing for query number : 164 / 2236
# Finished composing for query number : 165 / 2236
# Finished composing for query number : 166 / 2236
# Finished composing for query number : 167 / 2236
# Finished composing for query number : 168 / 2236
# Finished composing for query number : 169 / 2236
# Finished composing for query number : 170 / 2236
# Finished composing for query number : 171 / 2236
# Finished composing for query number : 172 / 2236
# Finished composing for query number : 173 / 2236
# Finished composing for query number : 174 / 2236
# Finished composing for query number : 175 / 2236
# Finished composing for query number : 176 / 2236
# Finished composing for query number : 177 / 2236
# Finished composing for query number : 178 / 2236
# Finished composing for query number : 179 / 2236
# Finished composing for query number : 180 / 2236
# Finished composing for query number : 181 / 2236
# Finished composing for query number : 182 / 2236
# Finished composing for query number : 183 / 2236
# Finished composing for query number : 184 / 2236
# Finished composing for query number : 185 / 2236
# Finished composing for query number : 186 / 2236
# Finished composing for query number : 187 / 2236
# Finished composing for query number : 188 / 2236
# Finished composing for query number : 189 / 2236
# Finished composing for query number : 190 / 2236
# Finished composing for query number : 191 / 2236
# Finished composing for query number : 192 / 2236
# Finished composing for query number : 193 / 2236
# Finished composing for query number : 194 / 2236
# Finished composing for query number : 195 / 2236
# Finished composing for query number : 196 / 2236
# Finished composing for query number : 197 / 2236
# Finished composing for query number : 198 / 2236
# Finished composing for query number : 199 / 2236
# Finished composing for query number : 200 / 2236
# Finished composing for query number : 201 / 2236
# Finished composing for query number : 202 / 2236
# Finished composing for query number : 203 / 2236
# Finished composing for query number : 204 / 2236
# Finished composing for query number : 205 / 2236
# Finished composing for query number : 206 / 2236
# Finished composing for query number : 207 / 2236
# Finished composing for query number : 208 / 2236
# Finished composing for query number : 209 / 2236
# Finished composing for query number : 210 / 2236
# Finished composing for query number : 211 / 2236
# Finished composing for query number : 212 / 2236
# Finished composing for query number : 213 / 2236
# Finished composing for query number : 214 / 2236
# Finished composing for query number : 215 / 2236
# Finished composing for query number : 216 / 2236
# Finished composing for query number : 217 / 2236
# Finished composing for query number : 218 / 2236
# Finished composing for query number : 219 / 2236
# Finished composing for query number : 220 / 2236
# Finished composing for query number : 221 / 2236
# Finished composing for query number : 222 / 2236
# Finished composing for query number : 223 / 2236
# Finished composing for query number : 224 / 2236
# Finished composing for query number : 225 / 2236
# Finished composing for query number : 226 / 2236
# Finished composing for query number : 227 / 2236
# Finished composing for query number : 228 / 2236
# Finished composing for query number : 229 / 2236
# Finished composing for query number : 230 / 2236
# Finished composing for query number : 231 / 2236
# Finished composing for query number : 232 / 2236
# Finished composing for query number : 233 / 2236
# Finished composing for query number : 234 / 2236
# Finished composing for query number : 235 / 2236
# Finished composing for query number : 236 / 2236
# Finished composing for query number : 237 / 2236
# Finished composing for query number : 238 / 2236
# Finished composing for query number : 239 / 2236
# Finished composing for query number : 240 / 2236
# Finished composing for query number : 241 / 2236
# Finished composing for query number : 242 / 2236
# Finished composing for query number : 243 / 2236
# Finished composing for query number : 244 / 2236
# Finished composing for query number : 245 / 2236
# Finished composing for query number : 246 / 2236
# Finished composing for query number : 247 / 2236
# Finished composing for query number : 248 / 2236
# Finished composing for query number : 249 / 2236
# Finished composing for query number : 250 / 2236
# Finished composing for query number : 251 / 2236
# Finished composing for query number : 252 / 2236
# Finished composing for query number : 253 / 2236
# Finished composing for query number : 254 / 2236
# Finished composing for query number : 255 / 2236
# Finished composing for query number : 256 / 2236
# Finished composing for query number : 257 / 2236
# Finished composing for query number : 258 / 2236
# Finished composing for query number : 259 / 2236
# Finished composing for query number : 260 / 2236
# Finished composing for query number : 261 / 2236
# Finished composing for query number : 262 / 2236
# Finished composing for query number : 263 / 2236
# Finished composing for query number : 264 / 2236
# Finished composing for query number : 265 / 2236
# Finished composing for query number : 266 / 2236
# Finished composing for query number : 267 / 2236
# Finished composing for query number : 268 / 2236
# Finished composing for query number : 269 / 2236
# Finished composing for query number : 270 / 2236
# Finished composing for query number : 271 / 2236
# Finished composing for query number : 272 / 2236
# Finished composing for query number : 273 / 2236
# Finished composing for query number : 274 / 2236
# Finished composing for query number : 275 / 2236
# Finished composing for query number : 276 / 2236
# Finished composing for query number : 277 / 2236
# Finished composing for query number : 278 / 2236
# Finished composing for query number : 279 / 2236
# Finished composing for query number : 280 / 2236
# Finished composing for query number : 281 / 2236
# Finished composing for query number : 282 / 2236
# Finished composing for query number : 283 / 2236
# Finished composing for query number : 284 / 2236
# Finished composing for query number : 285 / 2236
# Finished composing for query number : 286 / 2236
# Finished composing for query number : 287 / 2236
# Finished composing for query number : 288 / 2236
# Finished composing for query number : 289 / 2236
# Finished composing for query number : 290 / 2236
# Finished composing for query number : 291 / 2236
# Finished composing for query number : 292 / 2236
# Finished composing for query number : 293 / 2236
# Finished composing for query number : 294 / 2236
# Finished composing for query number : 295 / 2236
# Finished composing for query number : 296 / 2236
# Finished composing for query number : 297 / 2236
# Finished composing for query number : 298 / 2236
# Finished composing for query number : 299 / 2236
# Finished composing for query number : 300 / 2236
# Finished composing for query number : 301 / 2236
# Finished composing for query number : 302 / 2236
# Finished composing for query number : 303 / 2236
# Finished composing for query number : 304 / 2236
# Finished composing for query number : 305 / 2236
# Finished composing for query number : 306 / 2236
# Finished composing for query number : 307 / 2236
# Finished composing for query number : 308 / 2236
# Finished composing for query number : 309 / 2236
# Finished composing for query number : 310 / 2236
# Finished composing for query number : 311 / 2236
# Finished composing for query number : 312 / 2236
# Finished composing for query number : 313 / 2236
# Finished composing for query number : 314 / 2236
# Finished composing for query number : 315 / 2236
# Finished composing for query number : 316 / 2236
# Finished composing for query number : 317 / 2236
# Finished composing for query number : 318 / 2236
# Finished composing for query number : 319 / 2236
# Finished composing for query number : 320 / 2236
# Finished composing for query number : 321 / 2236
# Finished composing for query number : 322 / 2236
# Finished composing for query number : 323 / 2236
# Finished composing for query number : 324 / 2236
# Finished composing for query number : 325 / 2236
# Finished composing for query number : 326 / 2236
# Finished composing for query number : 327 / 2236
# Finished composing for query number : 328 / 2236
# Finished composing for query number : 329 / 2236
# Finished composing for query number : 330 / 2236
# Finished composing for query number : 331 / 2236
# Finished composing for query number : 332 / 2236
# Finished composing for query number : 333 / 2236
# Finished composing for query number : 334 / 2236
# Finished composing for query number : 335 / 2236
# Finished composing for query number : 336 / 2236
# Finished composing for query number : 337 / 2236
# Finished composing for query number : 338 / 2236
# Finished composing for query number : 339 / 2236
# Finished composing for query number : 340 / 2236
# Finished composing for query number : 341 / 2236
# Finished composing for query number : 342 / 2236
# Finished composing for query number : 343 / 2236
# Finished composing for query number : 344 / 2236
# Finished composing for query number : 345 / 2236
# Finished composing for query number : 346 / 2236
# Finished composing for query number : 347 / 2236
# Finished composing for query number : 348 / 2236
# Finished composing for query number : 349 / 2236
# Finished composing for query number : 350 / 2236
# Finished composing for query number : 351 / 2236
# Finished composing for query number : 352 / 2236
# Finished composing for query number : 353 / 2236
# Finished composing for query number : 354 / 2236
# Finished composing for query number : 355 / 2236
# Finished composing for query number : 356 / 2236
# Finished composing for query number : 357 / 2236
# Finished composing for query number : 358 / 2236
# Finished composing for query number : 359 / 2236
# Finished composing for query number : 360 / 2236
# Finished composing for query number : 361 / 2236
# Finished composing for query number : 362 / 2236
# Finished composing for query number : 363 / 2236
# Finished composing for query number : 364 / 2236
# Finished composing for query number : 365 / 2236
# Finished composing for query number : 366 / 2236
# Finished composing for query number : 367 / 2236
# Finished composing for query number : 368 / 2236
# Finished composing for query number : 369 / 2236
# Finished composing for query number : 370 / 2236
# Finished composing for query number : 371 / 2236
# Finished composing for query number : 372 / 2236
# Finished composing for query number : 373 / 2236
# Finished composing for query number : 374 / 2236
# Finished composing for query number : 375 / 2236
# Finished composing for query number : 376 / 2236
# Finished composing for query number : 377 / 2236
# Finished composing for query number : 378 / 2236
# Finished composing for query number : 379 / 2236
# Finished composing for query number : 380 / 2236
# Finished composing for query number : 381 / 2236
# Finished composing for query number : 382 / 2236
# Finished composing for query number : 383 / 2236
# Finished composing for query number : 384 / 2236
# Finished composing for query number : 385 / 2236
# Finished composing for query number : 386 / 2236
# Finished composing for query number : 387 / 2236
# Finished composing for query number : 388 / 2236
# Finished composing for query number : 389 / 2236
# Finished composing for query number : 390 / 2236
# Finished composing for query number : 391 / 2236
# Finished composing for query number : 392 / 2236
# Finished composing for query number : 393 / 2236
# Finished composing for query number : 394 / 2236
# Finished composing for query number : 395 / 2236
# Finished composing for query number : 396 / 2236
# Finished composing for query number : 397 / 2236
# Finished composing for query number : 398 / 2236
# Finished composing for query number : 399 / 2236
# Finished composing for query number : 400 / 2236
# Finished composing for query number : 401 / 2236
# Finished composing for query number : 402 / 2236
# Finished composing for query number : 403 / 2236
# Finished composing for query number : 404 / 2236
# Finished composing for query number : 405 / 2236
# Finished composing for query number : 406 / 2236
# Finished composing for query number : 407 / 2236
# Finished composing for query number : 408 / 2236
# Finished composing for query number : 409 / 2236
# Finished composing for query number : 410 / 2236
# Finished composing for query number : 411 / 2236
# Finished composing for query number : 412 / 2236
# Finished composing for query number : 413 / 2236
# Finished composing for query number : 414 / 2236
# Finished composing for query number : 415 / 2236
# Finished composing for query number : 416 / 2236
# Finished composing for query number : 417 / 2236
# Finished composing for query number : 418 / 2236
# Finished composing for query number : 419 / 2236
# Finished composing for query number : 420 / 2236
# Finished composing for query number : 421 / 2236
# Finished composing for query number : 422 / 2236
# Finished composing for query number : 423 / 2236
# Finished composing for query number : 424 / 2236
# Finished composing for query number : 425 / 2236
# Finished composing for query number : 426 / 2236
# Finished composing for query number : 427 / 2236
# Finished composing for query number : 428 / 2236
# Finished composing for query number : 429 / 2236
# Finished composing for query number : 430 / 2236
# Finished composing for query number : 431 / 2236
# Finished composing for query number : 432 / 2236
# Finished composing for query number : 433 / 2236
# Finished composing for query number : 434 / 2236
# Finished composing for query number : 435 / 2236
# Finished composing for query number : 436 / 2236
# Finished composing for query number : 437 / 2236
# Finished composing for query number : 438 / 2236
# Finished composing for query number : 439 / 2236
# Finished composing for query number : 440 / 2236
# Finished composing for query number : 441 / 2236
# Finished composing for query number : 442 / 2236
# Finished composing for query number : 443 / 2236
# Finished composing for query number : 444 / 2236
# Finished composing for query number : 445 / 2236
# Finished composing for query number : 446 / 2236
# Finished composing for query number : 447 / 2236
# Finished composing for query number : 448 / 2236
# Finished composing for query number : 449 / 2236
# Finished composing for query number : 450 / 2236
# Finished composing for query number : 451 / 2236
# Finished composing for query number : 452 / 2236
# Finished composing for query number : 453 / 2236
# Finished composing for query number : 454 / 2236
# Finished composing for query number : 455 / 2236
# Finished composing for query number : 456 / 2236
# Finished composing for query number : 457 / 2236
# Finished composing for query number : 458 / 2236
# Finished composing for query number : 459 / 2236
# Finished composing for query number : 460 / 2236
# Finished composing for query number : 461 / 2236
# Finished composing for query number : 462 / 2236
# Finished composing for query number : 463 / 2236
# Finished composing for query number : 464 / 2236
# Finished composing for query number : 465 / 2236
# Finished composing for query number : 466 / 2236
# Finished composing for query number : 467 / 2236
# Finished composing for query number : 468 / 2236
# Finished composing for query number : 469 / 2236
# Finished composing for query number : 470 / 2236
# Finished composing for query number : 471 / 2236
# Finished composing for query number : 472 / 2236
# Finished composing for query number : 473 / 2236
# Finished composing for query number : 474 / 2236
# Finished composing for query number : 475 / 2236
# Finished composing for query number : 476 / 2236
# Finished composing for query number : 477 / 2236
# Finished composing for query number : 478 / 2236
# Finished composing for query number : 479 / 2236
# Finished composing for query number : 480 / 2236
# Finished composing for query number : 481 / 2236
# Finished composing for query number : 482 / 2236
# Finished composing for query number : 483 / 2236
# Finished composing for query number : 484 / 2236
# Finished composing for query number : 485 / 2236
# Finished composing for query number : 486 / 2236
# Finished composing for query number : 487 / 2236
# Finished composing for query number : 488 / 2236
# Finished composing for query number : 489 / 2236
# Finished composing for query number : 490 / 2236
# Finished composing for query number : 491 / 2236
# Finished composing for query number : 492 / 2236
# Finished composing for query number : 493 / 2236
# Finished composing for query number : 494 / 2236
# Finished composing for query number : 495 / 2236
# Finished composing for query number : 496 / 2236
# Finished composing for query number : 497 / 2236
# Finished composing for query number : 498 / 2236
# Finished composing for query number : 499 / 2236
# Finished composing for query number : 500 / 2236
# Finished composing for query number : 501 / 2236
# Finished composing for query number : 502 / 2236
# Finished composing for query number : 503 / 2236
# Finished composing for query number : 504 / 2236
# Finished composing for query number : 505 / 2236
# Finished composing for query number : 506 / 2236
# Finished composing for query number : 507 / 2236
# Finished composing for query number : 508 / 2236
# Finished composing for query number : 509 / 2236
# Finished composing for query number : 510 / 2236
# Finished composing for query number : 511 / 2236
# Finished composing for query number : 512 / 2236
# Finished composing for query number : 513 / 2236
# Finished composing for query number : 514 / 2236
# Finished composing for query number : 515 / 2236
# Finished composing for query number : 516 / 2236
# Finished composing for query number : 517 / 2236
# Finished composing for query number : 518 / 2236
# Finished composing for query number : 519 / 2236
# Finished composing for query number : 520 / 2236
# Finished composing for query number : 521 / 2236
# Finished composing for query number : 522 / 2236
# Finished composing for query number : 523 / 2236
# Finished composing for query number : 524 / 2236
# Finished composing for query number : 525 / 2236
# Finished composing for query number : 526 / 2236
# Finished composing for query number : 527 / 2236
# Finished composing for query number : 528 / 2236
# Finished composing for query number : 529 / 2236
# Finished composing for query number : 530 / 2236
# Finished composing for query number : 531 / 2236
# Finished composing for query number : 532 / 2236
# Finished composing for query number : 533 / 2236
# Finished composing for query number : 534 / 2236
# Finished composing for query number : 535 / 2236
# Finished composing for query number : 536 / 2236
# Finished composing for query number : 537 / 2236
# Finished composing for query number : 538 / 2236
# Finished composing for query number : 539 / 2236
# Finished composing for query number : 540 / 2236
# Finished composing for query number : 541 / 2236
# Finished composing for query number : 542 / 2236
# Finished composing for query number : 543 / 2236
# Finished composing for query number : 544 / 2236
# Finished composing for query number : 545 / 2236
# Finished composing for query number : 546 / 2236
# Finished composing for query number : 547 / 2236
# Finished composing for query number : 548 / 2236
# Finished composing for query number : 549 / 2236
# Finished composing for query number : 550 / 2236
# Finished composing for query number : 551 / 2236
# Finished composing for query number : 552 / 2236
# Finished composing for query number : 553 / 2236
# Finished composing for query number : 554 / 2236
# Finished composing for query number : 555 / 2236
# Finished composing for query number : 556 / 2236
# Finished composing for query number : 557 / 2236
# Finished composing for query number : 558 / 2236
# Finished composing for query number : 559 / 2236
# Finished composing for query number : 560 / 2236
# Finished composing for query number : 561 / 2236
# Finished composing for query number : 562 / 2236
# Finished composing for query number : 563 / 2236
# Finished composing for query number : 564 / 2236
# Finished composing for query number : 565 / 2236
# Finished composing for query number : 566 / 2236
# Finished composing for query number : 567 / 2236
# Finished composing for query number : 568 / 2236
# Finished composing for query number : 569 / 2236
# Finished composing for query number : 570 / 2236
# Finished composing for query number : 571 / 2236
# Finished composing for query number : 572 / 2236
# Finished composing for query number : 573 / 2236
# Finished composing for query number : 574 / 2236
# Finished composing for query number : 575 / 2236
# Finished composing for query number : 576 / 2236
# Finished composing for query number : 577 / 2236
# Finished composing for query number : 578 / 2236
# Finished composing for query number : 579 / 2236
# Finished composing for query number : 580 / 2236
# Finished composing for query number : 581 / 2236
# Finished composing for query number : 582 / 2236
# Finished composing for query number : 583 / 2236
# Finished composing for query number : 584 / 2236
# Finished composing for query number : 585 / 2236
# Finished composing for query number : 586 / 2236
# Finished composing for query number : 587 / 2236
# Finished composing for query number : 588 / 2236
# Finished composing for query number : 589 / 2236
# Finished composing for query number : 590 / 2236
# Finished composing for query number : 591 / 2236
# Finished composing for query number : 592 / 2236
# Finished composing for query number : 593 / 2236
# Finished composing for query number : 594 / 2236
# Finished composing for query number : 595 / 2236
# Finished composing for query number : 596 / 2236
# Finished composing for query number : 597 / 2236
# Finished composing for query number : 598 / 2236
# Finished composing for query number : 599 / 2236
# Finished composing for query number : 600 / 2236
# Finished composing for query number : 601 / 2236
# Finished composing for query number : 602 / 2236
# Finished composing for query number : 603 / 2236
# Finished composing for query number : 604 / 2236
# Finished composing for query number : 605 / 2236
# Finished composing for query number : 606 / 2236
# Finished composing for query number : 607 / 2236
# Finished composing for query number : 608 / 2236
# Finished composing for query number : 609 / 2236
# Finished composing for query number : 610 / 2236
# Finished composing for query number : 611 / 2236
# Finished composing for query number : 612 / 2236
# Finished composing for query number : 613 / 2236
# Finished composing for query number : 614 / 2236
# Finished composing for query number : 615 / 2236
# Finished composing for query number : 616 / 2236
# Finished composing for query number : 617 / 2236
# Finished composing for query number : 618 / 2236
# Finished composing for query number : 619 / 2236
# Finished composing for query number : 620 / 2236
# Finished composing for query number : 621 / 2236
# Finished composing for query number : 622 / 2236
# Finished composing for query number : 623 / 2236
# Finished composing for query number : 624 / 2236
# Finished composing for query number : 625 / 2236
# Finished composing for query number : 626 / 2236
# Finished composing for query number : 627 / 2236
# Finished composing for query number : 628 / 2236
# Finished composing for query number : 629 / 2236
# Finished composing for query number : 630 / 2236
# Finished composing for query number : 631 / 2236
# Finished composing for query number : 632 / 2236
# Finished composing for query number : 633 / 2236
# Finished composing for query number : 634 / 2236
# Finished composing for query number : 635 / 2236
# Finished composing for query number : 636 / 2236
# Finished composing for query number : 637 / 2236
# Finished composing for query number : 638 / 2236
# Finished composing for query number : 639 / 2236
# Finished composing for query number : 640 / 2236
# Finished composing for query number : 641 / 2236
# Finished composing for query number : 642 / 2236
# Finished composing for query number : 643 / 2236
# Finished composing for query number : 644 / 2236
# Finished composing for query number : 645 / 2236
# Finished composing for query number : 646 / 2236
# Finished composing for query number : 647 / 2236
# Finished composing for query number : 648 / 2236
# Finished composing for query number : 649 / 2236
# Finished composing for query number : 650 / 2236
# Finished composing for query number : 651 / 2236
# Finished composing for query number : 652 / 2236
# Finished composing for query number : 653 / 2236
# Finished composing for query number : 654 / 2236
# Finished composing for query number : 655 / 2236
# Finished composing for query number : 656 / 2236
# Finished composing for query number : 657 / 2236
# Finished composing for query number : 658 / 2236
# Finished composing for query number : 659 / 2236
# Finished composing for query number : 660 / 2236
# Finished composing for query number : 661 / 2236
# Finished composing for query number : 662 / 2236
# Finished composing for query number : 663 / 2236
# Finished composing for query number : 664 / 2236
# Finished composing for query number : 665 / 2236
# Finished composing for query number : 666 / 2236
# Finished composing for query number : 667 / 2236
# Finished composing for query number : 668 / 2236
# Finished composing for query number : 669 / 2236
# Finished composing for query number : 670 / 2236
# Finished composing for query number : 671 / 2236
# Finished composing for query number : 672 / 2236
# Finished composing for query number : 673 / 2236
# Finished composing for query number : 674 / 2236
# Finished composing for query number : 675 / 2236
# Finished composing for query number : 676 / 2236
# Finished composing for query number : 677 / 2236
# Finished composing for query number : 678 / 2236
# Finished composing for query number : 679 / 2236
# Finished composing for query number : 680 / 2236
# Finished composing for query number : 681 / 2236
# Finished composing for query number : 682 / 2236
# Finished composing for query number : 683 / 2236
# Finished composing for query number : 684 / 2236
# Finished composing for query number : 685 / 2236
# Finished composing for query number : 686 / 2236
# Finished composing for query number : 687 / 2236
# Finished composing for query number : 688 / 2236
# Finished composing for query number : 689 / 2236
# Finished composing for query number : 690 / 2236
# Finished composing for query number : 691 / 2236
# Finished composing for query number : 692 / 2236
# Finished composing for query number : 693 / 2236
# Finished composing for query number : 694 / 2236
# Finished composing for query number : 695 / 2236
# Finished composing for query number : 696 / 2236
# Finished composing for query number : 697 / 2236
# Finished composing for query number : 698 / 2236
# Finished composing for query number : 699 / 2236
# Finished composing for query number : 700 / 2236
# Finished composing for query number : 701 / 2236
# Finished composing for query number : 702 / 2236
# Finished composing for query number : 703 / 2236
# Finished composing for query number : 704 / 2236
# Finished composing for query number : 705 / 2236
# Finished composing for query number : 706 / 2236
# Finished composing for query number : 707 / 2236
# Finished composing for query number : 708 / 2236
# Finished composing for query number : 709 / 2236
# Finished composing for query number : 710 / 2236
# Finished composing for query number : 711 / 2236
# Finished composing for query number : 712 / 2236
# Finished composing for query number : 713 / 2236
# Finished composing for query number : 714 / 2236
# Finished composing for query number : 715 / 2236
# Finished composing for query number : 716 / 2236
# Finished composing for query number : 717 / 2236
# Finished composing for query number : 718 / 2236
# Finished composing for query number : 719 / 2236
# Finished composing for query number : 720 / 2236
# Finished composing for query number : 721 / 2236
# Finished composing for query number : 722 / 2236
# Finished composing for query number : 723 / 2236
# Finished composing for query number : 724 / 2236
# Finished composing for query number : 725 / 2236
# Finished composing for query number : 726 / 2236
# Finished composing for query number : 727 / 2236
# Finished composing for query number : 728 / 2236
# Finished composing for query number : 729 / 2236
# Finished composing for query number : 730 / 2236
# Finished composing for query number : 731 / 2236
# Finished composing for query number : 732 / 2236
# Finished composing for query number : 733 / 2236
# Finished composing for query number : 734 / 2236
# Finished composing for query number : 735 / 2236
# Finished composing for query number : 736 / 2236
# Finished composing for query number : 737 / 2236
# Finished composing for query number : 738 / 2236
# Finished composing for query number : 739 / 2236
# Finished composing for query number : 740 / 2236
# Finished composing for query number : 741 / 2236
# Finished composing for query number : 742 / 2236
# Finished composing for query number : 743 / 2236
# Finished composing for query number : 744 / 2236
# Finished composing for query number : 745 / 2236
# Finished composing for query number : 746 / 2236
# Finished composing for query number : 747 / 2236
# Finished composing for query number : 748 / 2236
# Finished composing for query number : 749 / 2236
# Finished composing for query number : 750 / 2236
# Finished composing for query number : 751 / 2236
# Finished composing for query number : 752 / 2236
# Finished composing for query number : 753 / 2236
# Finished composing for query number : 754 / 2236
# Finished composing for query number : 755 / 2236
# Finished composing for query number : 756 / 2236
# Finished composing for query number : 757 / 2236
# Finished composing for query number : 758 / 2236
# Finished composing for query number : 759 / 2236
# Finished composing for query number : 760 / 2236
# Finished composing for query number : 761 / 2236
# Finished composing for query number : 762 / 2236
# Finished composing for query number : 763 / 2236
# Finished composing for query number : 764 / 2236
# Finished composing for query number : 765 / 2236
# Finished composing for query number : 766 / 2236
# Finished composing for query number : 767 / 2236
# Finished composing for query number : 768 / 2236
# Finished composing for query number : 769 / 2236
# Finished composing for query number : 770 / 2236
# Finished composing for query number : 771 / 2236
# Finished composing for query number : 772 / 2236
# Finished composing for query number : 773 / 2236
# Finished composing for query number : 774 / 2236
# Finished composing for query number : 775 / 2236
# Finished composing for query number : 776 / 2236
# Finished composing for query number : 777 / 2236
# Finished composing for query number : 778 / 2236
# Finished composing for query number : 779 / 2236
# Finished composing for query number : 780 / 2236
# Finished composing for query number : 781 / 2236
# Finished composing for query number : 782 / 2236
# Finished composing for query number : 783 / 2236
# Finished composing for query number : 784 / 2236
# Finished composing for query number : 785 / 2236
# Finished composing for query number : 786 / 2236
# Finished composing for query number : 787 / 2236
# Finished composing for query number : 788 / 2236
# Finished composing for query number : 789 / 2236
# Finished composing for query number : 790 / 2236
# Finished composing for query number : 791 / 2236
# Finished composing for query number : 792 / 2236
# Finished composing for query number : 793 / 2236
# Finished composing for query number : 794 / 2236
# Finished composing for query number : 795 / 2236
# Finished composing for query number : 796 / 2236
# Finished composing for query number : 797 / 2236
# Finished composing for query number : 798 / 2236
# Finished composing for query number : 799 / 2236
# Finished composing for query number : 800 / 2236
# Finished composing for query number : 801 / 2236
# Finished composing for query number : 802 / 2236
# Finished composing for query number : 803 / 2236
# Finished composing for query number : 804 / 2236
# Finished composing for query number : 805 / 2236
# Finished composing for query number : 806 / 2236
# Finished composing for query number : 807 / 2236
# Finished composing for query number : 808 / 2236
# Finished composing for query number : 809 / 2236
# Finished composing for query number : 810 / 2236
# Finished composing for query number : 811 / 2236
# Finished composing for query number : 812 / 2236
# Finished composing for query number : 813 / 2236
# Finished composing for query number : 814 / 2236
# Finished composing for query number : 815 / 2236
# Finished composing for query number : 816 / 2236
# Finished composing for query number : 817 / 2236
# Finished composing for query number : 818 / 2236
# Finished composing for query number : 819 / 2236
# Finished composing for query number : 820 / 2236
# Finished composing for query number : 821 / 2236
# Finished composing for query number : 822 / 2236
# Finished composing for query number : 823 / 2236
# Finished composing for query number : 824 / 2236
# Finished composing for query number : 825 / 2236
# Finished composing for query number : 826 / 2236
# Finished composing for query number : 827 / 2236
# Finished composing for query number : 828 / 2236
# Finished composing for query number : 829 / 2236
# Finished composing for query number : 830 / 2236
# Finished composing for query number : 831 / 2236
# Finished composing for query number : 832 / 2236
# Finished composing for query number : 833 / 2236
# Finished composing for query number : 834 / 2236
# Finished composing for query number : 835 / 2236
# Finished composing for query number : 836 / 2236
# Finished composing for query number : 837 / 2236
# Finished composing for query number : 838 / 2236
# Finished composing for query number : 839 / 2236
# Finished composing for query number : 840 / 2236
# Finished composing for query number : 841 / 2236
# Finished composing for query number : 842 / 2236
# Finished composing for query number : 843 / 2236
# Finished composing for query number : 844 / 2236
# Finished composing for query number : 845 / 2236
# Finished composing for query number : 846 / 2236
# Finished composing for query number : 847 / 2236
# Finished composing for query number : 848 / 2236
# Finished composing for query number : 849 / 2236
# Finished composing for query number : 850 / 2236
# Finished composing for query number : 851 / 2236
# Finished composing for query number : 852 / 2236
# Finished composing for query number : 853 / 2236
# Finished composing for query number : 854 / 2236
# Finished composing for query number : 855 / 2236
# Finished composing for query number : 856 / 2236
# Finished composing for query number : 857 / 2236
# Finished composing for query number : 858 / 2236
# Finished composing for query number : 859 / 2236
# Finished composing for query number : 860 / 2236
# Finished composing for query number : 861 / 2236
# Finished composing for query number : 862 / 2236
# Finished composing for query number : 863 / 2236
# Finished composing for query number : 864 / 2236
# Finished composing for query number : 865 / 2236
# Finished composing for query number : 866 / 2236
# Finished composing for query number : 867 / 2236
# Finished composing for query number : 868 / 2236
# Finished composing for query number : 869 / 2236
# Finished composing for query number : 870 / 2236
# Finished composing for query number : 871 / 2236
# Finished composing for query number : 872 / 2236
# Finished composing for query number : 873 / 2236
# Finished composing for query number : 874 / 2236
# Finished composing for query number : 875 / 2236
# Finished composing for query number : 876 / 2236
# Finished composing for query number : 877 / 2236
# Finished composing for query number : 878 / 2236
# Finished composing for query number : 879 / 2236
# Finished composing for query number : 880 / 2236
# Finished composing for query number : 881 / 2236
# Finished composing for query number : 882 / 2236
# Finished composing for query number : 883 / 2236
# Finished composing for query number : 884 / 2236
# Finished composing for query number : 885 / 2236
# Finished composing for query number : 886 / 2236
# Finished composing for query number : 887 / 2236
# Finished composing for query number : 888 / 2236
# Finished composing for query number : 889 / 2236
# Finished composing for query number : 890 / 2236
# Finished composing for query number : 891 / 2236
# Finished composing for query number : 892 / 2236
# Finished composing for query number : 893 / 2236
# Finished composing for query number : 894 / 2236
# Finished composing for query number : 895 / 2236
# Finished composing for query number : 896 / 2236
# Finished composing for query number : 897 / 2236
# Finished composing for query number : 898 / 2236
# Finished composing for query number : 899 / 2236
# Finished composing for query number : 900 / 2236
# Finished composing for query number : 901 / 2236
# Finished composing for query number : 902 / 2236
# Finished composing for query number : 903 / 2236
# Finished composing for query number : 904 / 2236
# Finished composing for query number : 905 / 2236
# Finished composing for query number : 906 / 2236
# Finished composing for query number : 907 / 2236
# Finished composing for query number : 908 / 2236
# Finished composing for query number : 909 / 2236
# Finished composing for query number : 910 / 2236
# Finished composing for query number : 911 / 2236
# Finished composing for query number : 912 / 2236
# Finished composing for query number : 913 / 2236
# Finished composing for query number : 914 / 2236
# Finished composing for query number : 915 / 2236
# Finished composing for query number : 916 / 2236
# Finished composing for query number : 917 / 2236
# Finished composing for query number : 918 / 2236
# Finished composing for query number : 919 / 2236
# Finished composing for query number : 920 / 2236
# Finished composing for query number : 921 / 2236
# Finished composing for query number : 922 / 2236
# Finished composing for query number : 923 / 2236
# Finished composing for query number : 924 / 2236
# Finished composing for query number : 925 / 2236
# Finished composing for query number : 926 / 2236
# Finished composing for query number : 927 / 2236
# Finished composing for query number : 928 / 2236
# Finished composing for query number : 929 / 2236
# Finished composing for query number : 930 / 2236
# Finished composing for query number : 931 / 2236
# Finished composing for query number : 932 / 2236
# Finished composing for query number : 933 / 2236
# Finished composing for query number : 934 / 2236
# Finished composing for query number : 935 / 2236
# Finished composing for query number : 936 / 2236
# Finished composing for query number : 937 / 2236
# Finished composing for query number : 938 / 2236
# Finished composing for query number : 939 / 2236
# Finished composing for query number : 940 / 2236
# Finished composing for query number : 941 / 2236
# Finished composing for query number : 942 / 2236
# Finished composing for query number : 943 / 2236
# Finished composing for query number : 944 / 2236
# Finished composing for query number : 945 / 2236
# Finished composing for query number : 946 / 2236
# Finished composing for query number : 947 / 2236
# Finished composing for query number : 948 / 2236
# Finished composing for query number : 949 / 2236
# Finished composing for query number : 950 / 2236
# Finished composing for query number : 951 / 2236
# Finished composing for query number : 952 / 2236
# Finished composing for query number : 953 / 2236
# Finished composing for query number : 954 / 2236
# Finished composing for query number : 955 / 2236
# Finished composing for query number : 956 / 2236
# Finished composing for query number : 957 / 2236
# Finished composing for query number : 958 / 2236
# Finished composing for query number : 959 / 2236
# Finished composing for query number : 960 / 2236
# Finished composing for query number : 961 / 2236
# Finished composing for query number : 962 / 2236
# Finished composing for query number : 963 / 2236
# Finished composing for query number : 964 / 2236
# Finished composing for query number : 965 / 2236
# Finished composing for query number : 966 / 2236
# Finished composing for query number : 967 / 2236
# Finished composing for query number : 968 / 2236
# Finished composing for query number : 969 / 2236
# Finished composing for query number : 970 / 2236
# Finished composing for query number : 971 / 2236
# Finished composing for query number : 972 / 2236
# Finished composing for query number : 973 / 2236
# Finished composing for query number : 974 / 2236
# Finished composing for query number : 975 / 2236
# Finished composing for query number : 976 / 2236
# Finished composing for query number : 977 / 2236
# Finished composing for query number : 978 / 2236
# Finished composing for query number : 979 / 2236
# Finished composing for query number : 980 / 2236
# Finished composing for query number : 981 / 2236
# ...
# Finished composing for query number : 1919 / 2236
# Finished composing for query number : 1920 / 2236
# Finished composing for query number : 1921 / 2236
# Finished composing for query number : 1922 / 2236
# Finished composing for query number : 1923 / 2236
# Finished composing for query number : 1924 / 2236
# Finished composing for query number : 1925 / 2236
# Finished composing for query number : 1926 / 2236
# Finished composing for query number : 1927 / 2236
# Finished composing for query number : 1928 / 2236
# Finished composing for query number : 1929 / 2236
# Finished composing for query number : 1930 / 2236
# Finished composing for query number : 1931 / 2236
# Finished composing for query number : 1932 / 2236
# Finished composing for query number : 1933 / 2236
# Finished composing for query number : 1934 / 2236
# Finished composing for query number : 1935 / 2236
# Finished composing for query number : 1936 / 2236
# Finished composing for query number : 1937 / 2236
# Finished composing for query number : 1938 / 2236
# Finished composing for query number : 1939 / 2236
# Finished composing for query number : 1940 / 2236
# Finished composing for query number : 1941 / 2236
# Finished composing for query number : 1942 / 2236
# Finished composing for query number : 1943 / 2236
# Finished composing for query number : 1944 / 2236
# Finished composing for query number : 1945 / 2236
# Finished composing for query number : 1946 / 2236
# Finished composing for query number : 1947 / 2236
# Finished composing for query number : 1948 / 2236
# Finished composing for query number : 1949 / 2236
# Finished composing for query number : 1950 / 2236
# Finished composing for query number : 1951 / 2236
# Finished composing for query number : 1952 / 2236
# Finished composing for query number : 1953 / 2236
# Finished composing for query number : 1954 / 2236
# Finished composing for query number : 1955 / 2236
# Finished composing for query number : 1956 / 2236
# Finished composing for query number : 1957 / 2236
# Finished composing for query number : 1958 / 2236
# Finished composing for query number : 1959 / 2236
# Finished composing for query number : 1960 / 2236
# Finished composing for query number : 1961 / 2236
# Finished composing for query number : 1962 / 2236
# Finished composing for query number : 1963 / 2236
# Finished composing for query number : 1964 / 2236
# Finished composing for query number : 1965 / 2236
# Finished composing for query number : 1966 / 2236
# Finished composing for query number : 1967 / 2236
# Finished composing for query number : 1968 / 2236
# Finished composing for query number : 1969 / 2236
# Finished composing for query number : 1970 / 2236
# Finished composing for query number : 1971 / 2236
# Finished composing for query number : 1972 / 2236
# Finished composing for query number : 1973 / 2236
# Finished composing for query number : 1974 / 2236
# Finished composing for query number : 1975 / 2236
# Finished composing for query number : 1976 / 2236
# Finished composing for query number : 1977 / 2236
# Finished composing for query number : 1978 / 2236
# Finished composing for query number : 1979 / 2236
# Finished composing for query number : 1980 / 2236
# Finished composing for query number : 1981 / 2236
# Finished composing for query number : 1982 / 2236
# Finished composing for query number : 1983 / 2236
# Finished composing for query number : 1984 / 2236
# Finished composing for query number : 1985 / 2236
# Finished composing for query number : 1986 / 2236
# Finished composing for query number : 1987 / 2236
# Finished composing for query number : 1988 / 2236
# Finished composing for query number : 1989 / 2236
# Finished composing for query number : 1990 / 2236
# Finished composing for query number : 1991 / 2236
# Finished composing for query number : 1992 / 2236
# Finished composing for query number : 1993 / 2236
# Finished composing for query number : 1994 / 2236
# Finished composing for query number : 1995 / 2236
# Finished composing for query number : 1996 / 2236
# Finished composing for query number : 1997 / 2236
# Finished composing for query number : 1998 / 2236
# Finished composing for query number : 1999 / 2236
# Finished composing for query number : 2000 / 2236
# Finished composing for query number : 2001 / 2236
# Finished composing for query number : 2002 / 2236
# Finished composing for query number : 2003 / 2236
# Finished composing for query number : 2004 / 2236
# Finished composing for query number : 2005 / 2236
# Finished composing for query number : 2006 / 2236
# Finished composing for query number : 2007 / 2236
# Finished composing for query number : 2008 / 2236
# Finished composing for query number : 2009 / 2236
# Finished composing for query number : 2010 / 2236
# Finished composing for query number : 2011 / 2236
# Finished composing for query number : 2012 / 2236
# Finished composing for query number : 2013 / 2236
# Finished composing for query number : 2014 / 2236
# Finished composing for query number : 2015 / 2236
# Finished composing for query number : 2016 / 2236
# Finished composing for query number : 2017 / 2236
# Finished composing for query number : 2018 / 2236
# Finished composing for query number : 2019 / 2236
# Finished composing for query number : 2020 / 2236
# Finished composing for query number : 2021 / 2236
# Finished composing for query number : 2022 / 2236
# Finished composing for query number : 2023 / 2236
# Finished composing for query number : 2024 / 2236
# Finished composing for query number : 2025 / 2236
# Finished composing for query number : 2026 / 2236
# Finished composing for query number : 2027 / 2236
# Finished composing for query number : 2028 / 2236
# Finished composing for query number : 2029 / 2236
# Finished composing for query number : 2030 / 2236
# Finished composing for query number : 2031 / 2236
# Finished composing for query number : 2032 / 2236
# Finished composing for query number : 2033 / 2236
# Finished composing for query number : 2034 / 2236
# Finished composing for query number : 2035 / 2236
# Finished composing for query number : 2036 / 2236
# Finished composing for query number : 2037 / 2236
# Finished composing for query number : 2038 / 2236
# Finished composing for query number : 2039 / 2236
# Finished composing for query number : 2040 / 2236
# Finished composing for query number : 2041 / 2236
# Finished composing for query number : 2042 / 2236
# Finished composing for query number : 2043 / 2236
# Finished composing for query number : 2044 / 2236
# Finished composing for query number : 2045 / 2236
# Finished composing for query number : 2046 / 2236
# Finished composing for query number : 2047 / 2236
# Finished composing for query number : 2048 / 2236
# Finished composing for query number : 2049 / 2236
# Finished composing for query number : 2050 / 2236
# Finished composing for query number : 2051 / 2236
# Finished composing for query number : 2052 / 2236
# Finished composing for query number : 2053 / 2236
# Finished composing for query number : 2054 / 2236
# Finished composing for query number : 2055 / 2236
# Finished composing for query number : 2056 / 2236
# Finished composing for query number : 2057 / 2236
# Finished composing for query number : 2058 / 2236
# Finished composing for query number : 2059 / 2236
# Finished composing for query number : 2060 / 2236
# Finished composing for query number : 2061 / 2236
# Finished composing for query number : 2062 / 2236
# Finished composing for query number : 2063 / 2236
# Finished composing for query number : 2064 / 2236
# Finished composing for query number : 2065 / 2236
# Finished composing for query number : 2066 / 2236
# Finished composing for query number : 2067 / 2236
# Finished composing for query number : 2068 / 2236
# Finished composing for query number : 2069 / 2236
# Finished composing for query number : 2070 / 2236
# Finished composing for query number : 2071 / 2236
# Finished composing for query number : 2072 / 2236
# Finished composing for query number : 2073 / 2236
# Finished composing for query number : 2074 / 2236
# Finished composing for query number : 2075 / 2236
# Finished composing for query number : 2076 / 2236
# Finished composing for query number : 2077 / 2236
# Finished composing for query number : 2078 / 2236
# Finished composing for query number : 2079 / 2236
# Finished composing for query number : 2080 / 2236
# Finished composing for query number : 2081 / 2236
# Finished composing for query number : 2082 / 2236
# Finished composing for query number : 2083 / 2236
# Finished composing for query number : 2084 / 2236
# Finished composing for query number : 2085 / 2236
# Finished composing for query number : 2086 / 2236
# Finished composing for query number : 2087 / 2236
# Finished composing for query number : 2088 / 2236
# Finished composing for query number : 2089 / 2236
# Finished composing for query number : 2090 / 2236
# Finished composing for query number : 2091 / 2236
# Finished composing for query number : 2092 / 2236
# Finished composing for query number : 2093 / 2236
# Finished composing for query number : 2094 / 2236
# Finished composing for query number : 2095 / 2236
# Finished composing for query number : 2096 / 2236
# Finished composing for query number : 2097 / 2236
# Finished composing for query number : 2098 / 2236
# Finished composing for query number : 2099 / 2236
# Finished composing for query number : 2100 / 2236
# Finished composing for query number : 2101 / 2236
# Finished composing for query number : 2102 / 2236
# Finished composing for query number : 2103 / 2236
# Finished composing for query number : 2104 / 2236
# Finished composing for query number : 2105 / 2236
# Finished composing for query number : 2106 / 2236
# Finished composing for query number : 2107 / 2236
# Finished composing for query number : 2108 / 2236
# Finished composing for query number : 2109 / 2236
# Finished composing for query number : 2110 / 2236
# Finished composing for query number : 2111 / 2236
# Finished composing for query number : 2112 / 2236
# Finished composing for query number : 2113 / 2236
# Finished composing for query number : 2114 / 2236
# Finished composing for query number : 2115 / 2236
# Finished composing for query number : 2116 / 2236
# Finished composing for query number : 2117 / 2236
# Finished composing for query number : 2118 / 2236
# Finished composing for query number : 2119 / 2236
# Finished composing for query number : 2120 / 2236
# Finished composing for query number : 2121 / 2236
# Finished composing for query number : 2122 / 2236
# Finished composing for query number : 2123 / 2236
# Finished composing for query number : 2124 / 2236
# Finished composing for query number : 2125 / 2236
# Finished composing for query number : 2126 / 2236
# Finished composing for query number : 2127 / 2236
# Finished composing for query number : 2128 / 2236
# Finished composing for query number : 2129 / 2236
# Finished composing for query number : 2130 / 2236
# Finished composing for query number : 2131 / 2236
# Finished composing for query number : 2132 / 2236
# Finished composing for query number : 2133 / 2236
# Finished composing for query number : 2134 / 2236
# Finished composing for query number : 2135 / 2236
# Finished composing for query number : 2136 / 2236
# Finished composing for query number : 2137 / 2236
# Finished composing for query number : 2138 / 2236
# Finished composing for query number : 2139 / 2236
# Finished composing for query number : 2140 / 2236
# Finished composing for query number : 2141 / 2236
# Finished composing for query number : 2142 / 2236
# Finished composing for query number : 2143 / 2236
# Finished composing for query number : 2144 / 2236
# Finished composing for query number : 2145 / 2236
# Finished composing for query number : 2146 / 2236
# Finished composing for query number : 2147 / 2236
# Finished composing for query number : 2148 / 2236
# Finished composing for query number : 2149 / 2236
# Finished composing for query number : 2150 / 2236
# Finished composing for query number : 2151 / 2236
# Finished composing for query number : 2152 / 2236
# Finished composing for query number : 2153 / 2236
# Finished composing for query number : 2154 / 2236
# Finished composing for query number : 2155 / 2236
# Finished composing for query number : 2156 / 2236
# Finished composing for query number : 2157 / 2236
# Finished composing for query number : 2158 / 2236
# Finished composing for query number : 2159 / 2236
# Finished composing for query number : 2160 / 2236
# Finished composing for query number : 2161 / 2236
# Finished composing for query number : 2162 / 2236
# Finished composing for query number : 2163 / 2236
# Finished composing for query number : 2164 / 2236
# Finished composing for query number : 2165 / 2236
# Finished composing for query number : 2166 / 2236
# Finished composing for query number : 2167 / 2236
# Finished composing for query number : 2168 / 2236
# Finished composing for query number : 2169 / 2236
# Finished composing for query number : 2170 / 2236
# Finished composing for query number : 2171 / 2236
# Finished composing for query number : 2172 / 2236
# Finished composing for query number : 2173 / 2236
# Finished composing for query number : 2174 / 2236
# Finished composing for query number : 2175 / 2236
# Finished composing for query number : 2176 / 2236
# Finished composing for query number : 2177 / 2236
# Finished composing for query number : 2178 / 2236
# Finished composing for query number : 2179 / 2236
# Finished composing for query number : 2180 / 2236
# Finished composing for query number : 2181 / 2236
# Finished composing for query number : 2182 / 2236
# Finished composing for query number : 2183 / 2236
# Finished composing for query number : 2184 / 2236
# Finished composing for query number : 2185 / 2236
# Finished composing for query number : 2186 / 2236
# Finished composing for query number : 2187 / 2236
# Finished composing for query number : 2188 / 2236
# Finished composing for query number : 2189 / 2236
# Finished composing for query number : 2190 / 2236
# Finished composing for query number : 2191 / 2236
# Finished composing for query number : 2192 / 2236
# Finished composing for query number : 2193 / 2236
# Finished composing for query number : 2194 / 2236
# Finished composing for query number : 2195 / 2236
# Finished composing for query number : 2196 / 2236
# Finished composing for query number : 2197 / 2236
# Finished composing for query number : 2198 / 2236
# Finished composing for query number : 2199 / 2236
# Finished composing for query number : 2200 / 2236
# Finished composing for query number : 2201 / 2236
# Finished composing for query number : 2202 / 2236
# Finished composing for query number : 2203 / 2236
# Finished composing for query number : 2204 / 2236
# Finished composing for query number : 2205 / 2236
# Finished composing for query number : 2206 / 2236
# Finished composing for query number : 2207 / 2236
# Finished composing for query number : 2208 / 2236
# Finished composing for query number : 2209 / 2236
# Finished composing for query number : 2210 / 2236
# Finished composing for query number : 2211 / 2236
# Finished composing for query number : 2212 / 2236
# Finished composing for query number : 2213 / 2236
# Finished composing for query number : 2214 / 2236
# Finished composing for query number : 2215 / 2236
# Finished composing for query number : 2216 / 2236
# Finished composing for query number : 2217 / 2236
# Finished composing for query number : 2218 / 2236
# Finished composing for query number : 2219 / 2236
# Finished composing for query number : 2220 / 2236
# Finished composing for query number : 2221 / 2236
# Finished composing for query number : 2222 / 2236
# Finished composing for query number : 2223 / 2236
# Finished composing for query number : 2224 / 2236
# Finished composing for query number : 2225 / 2236
# Finished composing for query number : 2226 / 2236
# Finished composing for query number : 2227 / 2236
# Finished composing for query number : 2228 / 2236
# Finished composing for query number : 2229 / 2236
# Finished composing for query number : 2230 / 2236
# Finished composing for query number : 2231 / 2236
# Finished composing for query number : 2232 / 2236
# Finished composing for query number : 2233 / 2236
# Finished composing for query number : 2234 / 2236
# Finished composing for query number : 2235 / 2236
# Finished composing for query number : 2236 / 2236
#
# Missing query-doc pairs :  30
# Done train, val, and test !!!

# %%
! ls exp2_averageOf_cosineSim_entityOnly
# Out:
# ranked.test.relevance.txt

# %%
! ../Eval/trec_eval-master/trec_eval ../Eval/qrelsY1-test.V2.0/automatic-test.pages.cbor-hierarchical.qrels exp2_averageOf_cosineSim_entityOnly/ranked.test.relevance.txt  -m all_trec
# Out:
# runid                 	all	rchan31
# num_q                 	all	2236
# num_ret               	all	223331
# num_rel               	all	6123
# num_rel_ret           	all	2349
# map                   	all	0.0594
# gm_map                	all	0.0023
# Rprec                 	all	0.0348
# bpref                 	all	0.4689
# recip_rank            	all	0.0944
# iprec_at_recall_0.00  	all	0.0970
# iprec_at_recall_0.10  	all	0.0967
# iprec_at_recall_0.20  	all	0.0905
# iprec_at_recall_0.30  	all	0.0768
# iprec_at_recall_0.40  	all	0.0631
# iprec_at_recall_0.50  	all	0.0616
# iprec_at_recall_0.60  	all	0.0441
# iprec_at_recall_0.70  	all	0.0427
# iprec_at_recall_0.80  	all	0.0386
# iprec_at_recall_0.90  	all	0.0382
# iprec_at_recall_1.00  	all	0.0382
# P_5                   	all	0.0268
# P_10                  	all	0.0215
# P_15                  	all	0.0193
# P_20                  	all	0.0174
# P_30                  	all	0.0157
# P_100                 	all	0.0105
# P_200                 	all	0.0053
# P_500                 	all	0.0021
# P_1000                	all	0.0011
# recall_5              	all	0.0694
# recall_10             	all	0.1072
# recall_15             	all	0.1442
# recall_20             	all	0.1697
# recall_30             	all	0.2234
# recall_100            	all	0.4689
# recall_200            	all	0.4689
# recall_500            	all	0.4689
# recall_1000           	all	0.4689
# infAP                 	all	0.0594
# gm_bpref              	all	0.0169
# Rprec_mult_0.20       	all	0.0407
# Rprec_mult_0.40       	all	0.0368
# Rprec_mult_0.60       	all	0.0358
# Rprec_mult_0.80       	all	0.0349
# Rprec_mult_1.00       	all	0.0348
# Rprec_mult_1.20       	all	0.0320
# Rprec_mult_1.40       	all	0.0312
# Rprec_mult_1.60       	all	0.0308
# Rprec_mult_1.80       	all	0.0306
# Rprec_mult_2.00       	all	0.0303
# utility               	all	-97.7786
# 11pt_avg              	all	0.0625
# binG                  	all	0.1284
# G                     	all	0.1284
# ndcg                  	all	0.1547
# ndcg_rel              	all	0.1485
# Rndcg                 	all	0.0954
# ndcg_cut_5            	all	0.0551
# ndcg_cut_10           	all	0.0693
# ndcg_cut_15           	all	0.0809
# ndcg_cut_20           	all	0.0884
# ndcg_cut_30           	all	0.1025
# ndcg_cut_100          	all	0.1547
# ndcg_cut_200          	all	0.1547
# ndcg_cut_500          	all	0.1547
# ndcg_cut_1000         	all	0.1547
# map_cut_5             	all	0.0402
# map_cut_10            	all	0.0457
# map_cut_15            	all	0.0490
# map_cut_20            	all	0.0507
# map_cut_30            	all	0.0533
# map_cut_100           	all	0.0594
# map_cut_200           	all	0.0594
# map_cut_500           	all	0.0594
# map_cut_1000          	all	0.0594
# relative_P_5          	all	0.0702
# relative_P_10         	all	0.1073
# relative_P_15         	all	0.1442
# relative_P_20         	all	0.1697
# relative_P_30         	all	0.2234
# relative_P_100        	all	0.4689
# relative_P_200        	all	0.4689
# relative_P_500        	all	0.4689
# relative_P_1000       	all	0.4689
# success_1             	all	0.0416
# success_5             	all	0.1230
# success_10            	all	0.1928
# set_P                 	all	0.0106
# set_relative_P        	all	0.4689
# set_recall            	all	0.4689
# set_map               	all	0.0075
# set_F                 	all	0.0204
# num_nonrel_judged_ret 	all	0

# %%
! ../Eval/trec_eval-master/trec_eval ../Eval/qrelsY1-test.V2.0/automatic-test.pages.cbor-hierarchical.qrels exp2_averageOf_cosineSim_entityOnly/ranked.test.relevance.txt  -m all_trec > exp2_averageOf_cosineSim_entityOnly_trec_results.txt
